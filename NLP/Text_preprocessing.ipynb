# %%
# text preprocessing

# stop words


# Given paragraph
# Given paragraph
paragraph = """Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. 
Success never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, 
your dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. 
But remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. 
Life is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. 
Work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. 
When you achieve success, do not forget the people who helped you and do not ignore those who still need your support. 
Be humble, stay strong, and always remember – your attitude decides your altitude. This is not just a dialogue, this is the truth of life. 
So stand up, fight for your dreams, and make your life an inspiration for others.."""

# %%
paragraph
# Out:
# 'Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. \nSuccess never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, \nyour dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. \nBut remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. \nLife is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. \nWork hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. \nWhen you achieve success, do not forget the people who helped you and do not ignore those who still ne
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer
steam = PorterStemmer()

# %%
nltk.sent_tokenize('paragraph')
# Out:
# ['paragraph']

# %%
# Tokenize into sentences
sentences = nltk.sent_tokenize(paragraph)

# Print result
print(sentences)
print(paragraph)
# Out:
# ['Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive.', 'Success never comes easy, and there are no shortcuts in the journey of life.', 'Every dream you see will test your strength, \nyour dedication, and your belief in yourself.', 'People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you.', 'But remember one thing, winners never quit and quitters never win.', 'If you fall, get up again, and if you fail, learn from that failure and start stronger than before.', 'Life is not about how many times you fall, it is about how many times you rise with confidence and hope.', 'Respect everyone, but never let anyone destroy your self-respect.', 'Work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges.', 'When you achieve success, do not forget the people who helped you and do not ignore 
# ...

# %%
type(sentences)
# Out:
# list

# %%
### apply stop words and filter and apply stemming

for i in range(len(sentences)):
    words = nltk.sent_tokenize(sentences[i])
    words = [steam.stem(word) for word in words if word not in set(stopwords.words("english"))]
    sentences[i] = ' ' .join(words) # converting all list of the words into sentence

# %%
sentences
# Out:
# ['friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive.',
#  'success never comes easy, and there are no shortcuts in the journey of life.',
#  'every dream you see will test your strength, \nyour dedication, and your belief in yourself.',
#  'people will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you.',
#  'but remember one thing, winners never quit and quitters never win.',
#  'if you fall, get up again, and if you fail, learn from that failure and start stronger than before.',
#  'life is not about how many times you fall, it is about how many times you rise with confidence and hope.',
#  'respect everyone, but never let anyone destroy your self-respect.',
#  'work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges.',
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download NLTK data if not already installed
nltk.download('punkt')
nltk.download('stopwords')

# Original paragraph
paragraph = """Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. 
Success never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, 
your dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. 
But remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. 
Life is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. 
Work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. 
When you achieve success, do not forget the people who helped you and do not ignore those who still need your support. 
Be humble, stay strong, and always remember – your attitude decides your altitude. This is not just a dialogue, this is the truth of life. 
So stand up, fight for your dreams, and make your life an inspiration for others.."""

# Tokenize words
words = word_tokenize(paragraph.lower())

# Stop words list
stop_words = set(stopwords.words('english'))

# Filter words: keep only alphabetic words that are not stopwords
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]

# Find removed stop words
removed_words = [word for word in words if word.isalpha() and word in stop_words]

# Output
print("✅ Original Word Count:", len(words))
print("✅ Filtered Word Count:", len(filtered_words))
print("\nFiltered Words (After Removing Stopwords):\n", filtered_words)
print("\nRemoved Stopwords:\n", removed_words)
# Out:
# ✅ Original Word Count: 253
# ✅ Filtered Word Count: 103
#
# Filtered Words (After Removing Stopwords):
# ...

# %%
# Given paragraph
# Given paragraph
paragraph = """Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. 
Success never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, 
your dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. 
But remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. 
Life is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. 
Work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. 
When you achieve success, do not forget the people who helped you and do not ignore those who still need your support. 
Be humble, stay strong, and always remember – your attitude decides your altitude. This is not just a dialogue, this is the truth of life. 
So stand up, fight for your dreams, and make your life an inspiration for others.."""

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# %%
# Download NLTK data if not already installed
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(paragraph)
# Out:
# Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive.
# Success never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength,
# your dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you.
# But remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before.
# Life is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect.
# Work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges.
# ...

# %%
word_tokenize(paragraph.lower())
# Out:
# ['friends',
#  ',',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  ',',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  '.',
#  'success',
#  'never',
#  'comes',
#  'easy',
#  ',',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcuts',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  '.',
#  'every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  ',',
#  'your',
#  'dedication',
#  ',',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  '.',
#  'people',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  ',',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  ',',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friends',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  '.',
#  'but',
#  'remember',
#  'one',
#  'thing',
#  ',',
#  'winners',
#  'never',
#  'quit',
# ...

# %%
words = word_tokenize(paragraph.lower())

# %%
stop_words= set(stopwords.words('english'))

# %%
[word for word in words if word.isalpha() and word not in stop_words]  ## Filter words: keep only alphabetic words that are not stopwords
# Out:
# ['friends',
#  'life',
#  'stage',
#  'battlefield',
#  'fight',
#  'courage',
#  'patience',
#  'survive',
#  'success',
#  'never',
#  'comes',
#  'easy',
#  'shortcuts',
#  'journey',
#  'life',
#  'every',
#  'dream',
#  'see',
#  'test',
#  'strength',
#  'dedication',
#  'belief',
#  'people',
#  'laugh',
#  'doubt',
#  'sometimes',
#  'even',
#  'closest',
#  'friends',
#  'turn',
#  'back',
#  'remember',
#  'one',
#  'thing',
#  'winners',
#  'never',
#  'quit',
#  'quitters',
#  'never',
#  'win',
#  'fall',
#  'get',
#  'fail',
#  'learn',
#  'failure',
#  'start',
#  'stronger',
#  'life',
#  'many',
#  'times',
#  'fall',
#  'many',
#  'times',
#  'rise',
#  'confidence',
#  'hope',
#  'respect',
#  'everyone',
#  'never',
#  'let',
#  'anyone',
#  'destroy',
#  'work',
#  'hard',
#  'one',
#  'watching',
#  'believe',
#  'nobody',
#  'else',
#  'keep',
#  'moving',
#  'forward',
#  'even',
#  'road',
#  'full',
#  'challenges',
#  'achieve',
#  'success',
#  'forget',
# ...

# %%
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]

# %%
[word for word in words if word.isalpha() and word in stop_words] # Find removed stop words
# Out:
# ['is',
#  'not',
#  'just',
#  'a',
#  'it',
#  'is',
#  'a',
#  'where',
#  'only',
#  'those',
#  'who',
#  'with',
#  'and',
#  'and',
#  'there',
#  'are',
#  'no',
#  'in',
#  'the',
#  'of',
#  'you',
#  'will',
#  'your',
#  'your',
#  'and',
#  'your',
#  'in',
#  'yourself',
#  'will',
#  'at',
#  'you',
#  'they',
#  'will',
#  'you',
#  'and',
#  'your',
#  'will',
#  'their',
#  'on',
#  'you',
#  'but',
#  'and',
#  'if',
#  'you',
#  'up',
#  'again',
#  'and',
#  'if',
#  'you',
#  'from',
#  'that',
#  'and',
#  'than',
#  'before',
#  'is',
#  'not',
#  'about',
#  'how',
#  'you',
#  'it',
#  'is',
#  'about',
#  'how',
#  'you',
#  'with',
#  'and',
#  'but',
#  'your',
#  'when',
#  'no',
#  'is',
#  'in',
#  'yourself',
#  'when',
#  'does',
#  'and',
#  'when',
#  'the',
#  'is',
#  'of',
#  'when',
#  'you',
#  'do',
#  'not',
#  'the',
#  'who',
#  'you',
#  'and',
#  'do',
#  'not',
#  'those',
#  'who',
#  'your',
#  'be',
#  'and',
#  'your',
#  'your',
# ...

# %%
removed_words = [word for word in words if word.isalpha() and word in stop_words]

# %%
print("Original word count:", len(words))
# Out:
# Original word count: 253

# %%
print("filtered word count:",len(filtered_words))
# Out:
# filtered word count: 103

# %%
print("\nfilterd words (after removing stopwords):\n",filtered_words)
# Out:
# filterd words (after removing stopwords):
# ...

# %%
# use snowball steammer method
from nltk.stem import SnowballStemmer

# %%
SnowballStemmer("english")

# %%
Snow = SnowballStemmer("english")

# %%
word_tokenize(paragraph.lower())
# Out:
# ['friends',
#  ',',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  ',',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  '.',
#  'success',
#  'never',
#  'comes',
#  'easy',
#  ',',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcuts',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  '.',
#  'every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  ',',
#  'your',
#  'dedication',
#  ',',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  '.',
#  'people',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  ',',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  ',',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friends',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  '.',
#  'but',
#  'remember',
#  'one',
#  'thing',
#  ',',
#  'winners',
#  'never',
#  'quit',
# ...

# %%
words2 = word_tokenize(paragraph.lower())

# %%
words2
# Out:
# ['friends',
#  ',',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  ',',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  '.',
#  'success',
#  'never',
#  'comes',
#  'easy',
#  ',',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcuts',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  '.',
#  'every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  ',',
#  'your',
#  'dedication',
#  ',',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  '.',
#  'people',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  ',',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  ',',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friends',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  '.',
#  'but',
#  'remember',
#  'one',
#  'thing',
#  ',',
#  'winners',
#  'never',
#  'quit',
# ...

# %%
[word for word in words if word.isalpha()]
# Out:
# ['friends',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  'success',
#  'never',
#  'comes',
#  'easy',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcuts',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  'every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  'your',
#  'dedication',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  'people',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friends',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  'but',
#  'remember',
#  'one',
#  'thing',
#  'winners',
#  'never',
#  'quit',
#  'and',
#  'quitters',
#  'never',
#  'win',
#  'if',
#  'you',
#  'fall',
#  'get',
#  'up',
# ...

# %%
words2= [word for word in words if word.isalpha()]

# %%
[steam.stem(word) for word in words2]
# Out:
# ['friend',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'onli',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courag',
#  'and',
#  'patienc',
#  'surviv',
#  'success',
#  'never',
#  'come',
#  'easi',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcut',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  'everi',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  'your',
#  'dedic',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  'peopl',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  'and',
#  'sometim',
#  'even',
#  'your',
#  'closest',
#  'friend',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  'but',
#  'rememb',
#  'one',
#  'thing',
#  'winner',
#  'never',
#  'quit',
#  'and',
#  'quitter',
#  'never',
#  'win',
#  'if',
#  'you',
#  'fall',
#  'get',
#  'up',
#  'again',
#  'and',
# ...

# %%
stemmed_words  = [steam.stem(word) for word in words2]

# %%
original_count = len(words2)

# %%
len(stemmed_words)
# Out:
# 217

# %%
stemmed_count = len(stemmed_words)

# %%
print(f"✅ Original Word Count: {original_count}")
print(f"✅ Stemmed Word Count: {stemmed_count}")
# Out:
# ✅ Original Word Count: 217
# ✅ Stemmed Word Count: 217

# %%
print("Original words:",words2[:50])
print("stemmed words:",steammed_words[:50])
# Out:
# Original words: ['friends', 'life', 'is', 'not', 'just', 'a', 'stage', 'it', 'is', 'a', 'battlefield', 'where', 'only', 'those', 'who', 'fight', 'with', 'courage', 'and', 'patience', 'survive', 'success', 'never', 'comes', 'easy', 'and', 'there', 'are', 'no', 'shortcuts', 'in', 'the', 'journey', 'of', 'life', 'every', 'dream', 'you', 'see', 'will', 'test', 'your', 'strength', 'your', 'dedication', 'and', 'your', 'belief', 'in', 'yourself']
# stemmed words: ['friend', 'life', 'is', 'not', 'just', 'a', 'stage', 'it', 'is', 'a', 'battlefield', 'where', 'onli', 'those', 'who', 'fight', 'with', 'courag', 'and', 'patienc', 'surviv', 'success', 'never', 'come', 'easi', 'and', 'there', 'are', 'no', 'shortcut', 'in', 'the', 'journey', 'of', 'life', 'everi', 'dream', 'you', 'see', 'will', 'test', 'your', 'strength', 'your', 'dedic', 'and', 'your', 'belief', 'in', 'yourself']

# %%
paragraph
# Out:
# 'Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. \nSuccess never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, \nyour dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. \nBut remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. \nLife is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. \nWork hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. \nWhen you achieve success, do not forget the people who helped you and do not ignore those who still ne
# ...

# %%
sentences
# Out:
# ['friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive.',
#  'success never comes easy, and there are no shortcuts in the journey of life.',
#  'every dream you see will test your strength, \nyour dedication, and your belief in yourself.',
#  'people will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you.',
#  'but remember one thing, winners never quit and quitters never win.',
#  'if you fall, get up again, and if you fail, learn from that failure and start stronger than before.',
#  'life is not about how many times you fall, it is about how many times you rise with confidence and hope.',
#  'respect everyone, but never let anyone destroy your self-respect.',
#  'work hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges.',
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# %%
# Download required resources (run this only once)

nltk.download('punk')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Error loading punk: Package 'punk' not found in index
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
paragraph
# Out:
# 'Friends, life is not just a stage, it is a battlefield where only those who fight with courage and patience survive. \nSuccess never comes easy, and there are no shortcuts in the journey of life. Every dream you see will test your strength, \nyour dedication, and your belief in yourself. People will laugh at you, they will doubt you, and sometimes even your closest friends will turn their back on you. \nBut remember one thing, winners never quit and quitters never win. If you fall, get up again, and if you fail, learn from that failure and start stronger than before. \nLife is not about how many times you fall, it is about how many times you rise with confidence and hope. Respect everyone, but never let anyone destroy your self-respect. \nWork hard when no one is watching, believe in yourself when nobody else does, and keep moving forward even when the road is full of challenges. \nWhen you achieve success, do not forget the people who helped you and do not ignore those who still ne
# ...

# %%
# Tokenize the paragraph into words
word_tokenize(paragraph)
# Out:
# ['Friends',
#  ',',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  ',',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  '.',
#  'Success',
#  'never',
#  'comes',
#  'easy',
#  ',',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcuts',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  '.',
#  'Every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  ',',
#  'your',
#  'dedication',
#  ',',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  '.',
#  'People',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  ',',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  ',',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friends',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  '.',
#  'But',
#  'remember',
#  'one',
#  'thing',
#  ',',
#  'winners',
#  'never',
#  'quit',
# ...

# %%
tokens = word_tokenize(paragraph)

# %%
Lemmatizer = WordNetLemmatizer()

# %%
[lemmitizer.lemmatize(word.lower()) for word in tokens]
# Out:
# ['friend',
#  ',',
#  'life',
#  'is',
#  'not',
#  'just',
#  'a',
#  'stage',
#  ',',
#  'it',
#  'is',
#  'a',
#  'battlefield',
#  'where',
#  'only',
#  'those',
#  'who',
#  'fight',
#  'with',
#  'courage',
#  'and',
#  'patience',
#  'survive',
#  '.',
#  'success',
#  'never',
#  'come',
#  'easy',
#  ',',
#  'and',
#  'there',
#  'are',
#  'no',
#  'shortcut',
#  'in',
#  'the',
#  'journey',
#  'of',
#  'life',
#  '.',
#  'every',
#  'dream',
#  'you',
#  'see',
#  'will',
#  'test',
#  'your',
#  'strength',
#  ',',
#  'your',
#  'dedication',
#  ',',
#  'and',
#  'your',
#  'belief',
#  'in',
#  'yourself',
#  '.',
#  'people',
#  'will',
#  'laugh',
#  'at',
#  'you',
#  ',',
#  'they',
#  'will',
#  'doubt',
#  'you',
#  ',',
#  'and',
#  'sometimes',
#  'even',
#  'your',
#  'closest',
#  'friend',
#  'will',
#  'turn',
#  'their',
#  'back',
#  'on',
#  'you',
#  '.',
#  'but',
#  'remember',
#  'one',
#  'thing',
#  ',',
#  'winner',
#  'never',
#  'quit',
# ...

# %%
lemmatized_words = [lemmitizer.lemmatize(word.lower()) for word in tokens]

# %%
''.join(lemmatized_words)
# Out:
# 'friend,lifeisnotjustastage,itisabattlefieldwhereonlythosewhofightwithcourageandpatiencesurvive.successnevercomeeasy,andtherearenoshortcutinthejourneyoflife.everydreamyouseewilltestyourstrength,yourdedication,andyourbeliefinyourself.peoplewilllaughatyou,theywilldoubtyou,andsometimesevenyourclosestfriendwillturntheirbackonyou.butrememberonething,winnerneverquitandquitterneverwin.ifyoufall,getupagain,andifyoufail,learnfromthatfailureandstartstrongerthanbefore.lifeisnotabouthowmanytimeyoufall,itisabouthowmanytimeyourisewithconfidenceandhope.respecteveryone,butneverletanyonedestroyyourself-respect.workhardwhennooneiswatching,believeinyourselfwhennobodyelsedoe,andkeepmovingforwardevenwhentheroadisfullofchallenge.whenyouachievesuccess,donotforgetthepeoplewhohelpedyouanddonotignorethosewhostillneedyoursupport.behumble,staystrong,andalwaysremember–yourattitudedecidesyouraltitude.thisisnotjustadialogue,thisisthetruthoflife.sostandup,fightforyourdream,andmakeyourlifeaninspirationforothers..'

# %%
lemmatized_text = ''.join(lemmatized_words)

# %%
lemmatized_text
# Out:
# 'friend,lifeisnotjustastage,itisabattlefieldwhereonlythosewhofightwithcourageandpatiencesurvive.successnevercomeeasy,andtherearenoshortcutinthejourneyoflife.everydreamyouseewilltestyourstrength,yourdedication,andyourbeliefinyourself.peoplewilllaughatyou,theywilldoubtyou,andsometimesevenyourclosestfriendwillturntheirbackonyou.butrememberonething,winnerneverquitandquitterneverwin.ifyoufall,getupagain,andifyoufail,learnfromthatfailureandstartstrongerthanbefore.lifeisnotabouthowmanytimeyoufall,itisabouthowmanytimeyourisewithconfidenceandhope.respecteveryone,butneverletanyonedestroyyourself-respect.workhardwhennooneiswatching,believeinyourselfwhennobodyelsedoe,andkeepmovingforwardevenwhentheroadisfullofchallenge.whenyouachievesuccess,donotforgetthepeoplewhohelpedyouanddonotignorethosewhostillneedyoursupport.behumble,staystrong,andalwaysremember–yourattitudedecidesyouraltitude.thisisnotjustadialogue,thisisthetruthoflife.sostandup,fightforyourdream,andmakeyourlifeaninspirationforothers..'

# %%
print(lemmatized_words)
# Out:
# ['friend', ',', 'life', 'is', 'not', 'just', 'a', 'stage', ',', 'it', 'is', 'a', 'battlefield', 'where', 'only', 'those', 'who', 'fight', 'with', 'courage', 'and', 'patience', 'survive', '.', 'success', 'never', 'come', 'easy', ',', 'and', 'there', 'are', 'no', 'shortcut', 'in', 'the', 'journey', 'of', 'life', '.', 'every', 'dream', 'you', 'see', 'will', 'test', 'your', 'strength', ',', 'your', 'dedication', ',', 'and', 'your', 'belief', 'in', 'yourself', '.', 'people', 'will', 'laugh', 'at', 'you', ',', 'they', 'will', 'doubt', 'you', ',', 'and', 'sometimes', 'even', 'your', 'closest', 'friend', 'will', 'turn', 'their', 'back', 'on', 'you', '.', 'but', 'remember', 'one', 'thing', ',', 'winner', 'never', 'quit', 'and', 'quitter', 'never', 'win', '.', 'if', 'you', 'fall', ',', 'get', 'up', 'again', ',', 'and', 'if', 'you', 'fail', ',', 'learn', 'from', 'that', 'failure', 'and', 'start', 'stronger', 'than', 'before', '.', 'life', 'is', 'not', 'about', 'how', 'many', 'time', 'you', 'fal
# ...

# %%
for i in range(len(sentences)):
    words3 = nltk.word_tokenize(sentences[i])
    words3= [lemmitizer.lemmatize(word) for word in words3 if word not in set(sentences)]
    sentences[i] = ''.join(lemmatized_words)

# %%
sentences
# Out:
# ['friend,lifeisnotjustastage,itisabattlefieldwhereonlythosewhofightwithcourageandpatiencesurvive.successnevercomeeasy,andtherearenoshortcutinthejourneyoflife.everydreamyouseewilltestyourstrength,yourdedication,andyourbeliefinyourself.peoplewilllaughatyou,theywilldoubtyou,andsometimesevenyourclosestfriendwillturntheirbackonyou.butrememberonething,winnerneverquitandquitterneverwin.ifyoufall,getupagain,andifyoufail,learnfromthatfailureandstartstrongerthanbefore.lifeisnotabouthowmanytimeyoufall,itisabouthowmanytimeyourisewithconfidenceandhope.respecteveryone,butneverletanyonedestroyyourself-respect.workhardwhennooneiswatching,believeinyourselfwhennobodyelsedoe,andkeepmovingforwardevenwhentheroadisfullofchallenge.whenyouachievesuccess,donotforgetthepeoplewhohelpedyouanddonotignorethosewhostillneedyoursupport.behumble,staystrong,andalwaysremember–yourattitudedecidesyouraltitude.thisisnotjustadialogue,thisisthetruthoflife.sostandup,fightforyourdream,andmakeyourlifeaninspirationforothers..',
# ...
