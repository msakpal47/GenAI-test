# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits):
    print(i)
# Out:
# (0, 'apple')
# (1, 'banana')
# (2, 'cherry')

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in range(len(fruits)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits):
    print(i,fruits)
# Out:
# (0, 'apple') ['apple', 'banana', 'cherry']
# (1, 'banana') ['apple', 'banana', 'cherry']
# (2, 'cherry') ['apple', 'banana', 'cherry']

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in range(len(fruits)):
    print(i,fruits)
# Out:
# 0 ['apple', 'banana', 'cherry']
# 1 ['apple', 'banana', 'cherry']
# 2 ['apple', 'banana', 'cherry']

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in range(len(fruits)):
    print(i,fruits)
# Out:
# 0 ['apple', 'banana', 'cherry']
# 1 ['apple', 'banana', 'cherry']
# 2 ['apple', 'banana', 'cherry']

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in range(len(fruits)):
    print(i + 1,fruits[i])
# Out:
# 1 apple
# 2 banana
# 3 cherry

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in range(len(fruits)):
    print(i,fruits[i])
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits):
    print(i,fruits)
# Out:
# (0, 'apple') ['apple', 'banana', 'cherry']
# (1, 'banana') ['apple', 'banana', 'cherry']
# (2, 'cherry') ['apple', 'banana', 'cherry']

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits[1:],start= 1):
    print(i)
# Out:
# (1, 'banana')
# (2, 'cherry')

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits[1:],start= 1):
    print(i,fruits)
# Out:
# (1, 'banana') ['apple', 'banana', 'cherry']
# (2, 'cherry') ['apple', 'banana', 'cherry']

# %%
# Simple Example with a List enumerate

fruits = ["apple", "banana", "cherry"]

for i in enumerate(fruits[1:],start= 1):
    print(i,fruits,1)
# Out:
# (1, 'banana') ['apple', 'banana', 'cherry'] 1
# (2, 'cherry') ['apple', 'banana', 'cherry'] 1
