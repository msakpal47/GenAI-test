# %%
# Text Preprocessing 
# Stemming is the process of reducing a word to its root or base form (called a stem) by removing suffixes and prefixes.

# ✅ Example:
# Word	Stem (by stemming)
# running	run
# studies	studi
# organization	organ
# flying	fli

# ⚠️ Notice that the stems may not always be real English words.

# %%
# classification Problem
# comment of product is a positive review or negative review
# Reviews  ------> eating , eat, eated

words = [
    "run", "running", "ran", "runs",
    "eat", "eating", "eaten", "eats",
    "go", "going", "gone", "goes",
    "do", "doing", "done", "does",
    "be", "is", "are", "was", "were", "being", "been",
    "have", "has", "had", "having",
    "fly", "flying", "flew", "flown",
    "write", "writing", "wrote", "written", "writes",
    "read", "reading", "reads",
    "drink", "drinking", "drank", "drunk", "drinks",
    "sleep", "sleeping", "slept", "sleeps",
    "speak", "speaking", "spoke", "spoken", "speaks",
    "break", "breaking", "broke", "broken", "breaks",
    "buy", "buying", "bought", "buys",
    "sell", "selling", "sold", "sells",
    "know", "knowing", "knew", "known", "knows",
    "think", "thinking", "thought", "thinks",
    "swim", "swimming", "swam", "swum", "swims",
    "build", "building", "built", "builds",
    "sing", "singing", "sang", "sung", "sings",
    "teach", "teaching", "taught", "teaches",
    "take", "taking", "took", "taken", "takes"
]

# %%
print(words)
# Out:
# ['run', 'running', 'ran', 'runs', 'eat', 'eating', 'eaten', 'eats', 'go', 'going', 'gone', 'goes', 'do', 'doing', 'done', 'does', 'be', 'is', 'are', 'was', 'were', 'being', 'been', 'have', 'has', 'had', 'having', 'fly', 'flying', 'flew', 'flown', 'write', 'writing', 'wrote', 'written', 'writes', 'read', 'reading', 'reads', 'drink', 'drinking', 'drank', 'drunk', 'drinks', 'sleep', 'sleeping', 'slept', 'sleeps', 'speak', 'speaking', 'spoke', 'spoken', 'speaks', 'break', 'breaking', 'broke', 'broken', 'breaks', 'buy', 'buying', 'bought', 'buys', 'sell', 'selling', 'sold', 'sells', 'know', 'knowing', 'knew', 'known', 'knows', 'think', 'thinking', 'thought', 'thinks', 'swim', 'swimming', 'swam', 'swum', 'swims', 'build', 'building', 'built', 'builds', 'sing', 'singing', 'sang', 'sung', 'sings', 'teach', 'teaching', 'taught', 'teaches', 'take', 'taking', 'took', 'taken', 'takes']

# %%
# ##  portalstemmer

# ✅ Porter Stemmer – Definition:
# The Porter Stemmer is a popular stemming algorithm in Natural Language Processing (NLP) that reduces words to their root form (called a "stem"). Developed by Martin Porter in 1980, it uses a series of rules to remove common morphological and inflectional endings from English words.


from nltk.stem import PorterStemmer

# %%
Stemmer = PorterStemmer()

# %%
# Apply stemming
for word in words:
    print(word +"---->"+ stemmer.stem(word))
# Out:
# run---->run
# running---->run
# ran---->ran
# runs---->run
# eat---->eat
# eating---->eat
# eaten---->eaten
# eats---->eat
# go---->go
# going---->go
# gone---->gone
# goes---->goe
# do---->do
# doing---->do
# done---->done
# does---->doe
# be---->be
# is---->is
# are---->are
# was---->wa
# were---->were
# being---->be
# been---->been
# have---->have
# has---->ha
# had---->had
# having---->have
# fly---->fli
# flying---->fli
# flew---->flew
# flown---->flown
# write---->write
# writing---->write
# wrote---->wrote
# written---->written
# writes---->write
# read---->read
# reading---->read
# reads---->read
# drink---->drink
# drinking---->drink
# drank---->drank
# drunk---->drunk
# drinks---->drink
# sleep---->sleep
# sleeping---->sleep
# slept---->slept
# sleeps---->sleep
# speak---->speak
# speaking---->speak
# spoke---->spoke
# spoken---->spoken
# speaks---->speak
# break---->break
# breaking---->break
# broke---->broke
# broken---->broken
# breaks---->break
# buy---->buy
# buying---->buy
# bought---->bought
# buys---->buy
# sell---->sell
# selling---->sell
# sold---->sold
# sells---->sell
# know---->know
# knowing---->know
# knew---->knew
# known---->known
# knows---->know
# think---->think
# thinking---->think
# thought---->thought
# thinks---->think
# swim---->swim
# swimming---->swim
# swam---->swam
# swum---->swum
# swims---->swim
# build---->build
# building---->build
# built---->built
# builds---->build
# sing---->sing
# singing---->sing
# sang---->sang
# sung---->sung
# sings---->sing
# teach---->teach
# teaching---->teach
# taught---->taught
# teaches---->teach
# take---->take
# taking---->take
# took---->took
# taken---->taken
# takes---->take

# %%
# Apply stemming
for word in words:
    print(word +"---->" + stemmer.stem(word))
# Out:
# run---->run
# running---->run
# ran---->ran
# runs---->run
# eat---->eat
# eating---->eat
# eaten---->eaten
# eats---->eat
# go---->go
# going---->go
# gone---->gone
# goes---->goe
# do---->do
# doing---->do
# done---->done
# does---->doe
# be---->be
# is---->is
# are---->are
# was---->wa
# were---->were
# being---->be
# been---->been
# have---->have
# has---->ha
# had---->had
# having---->have
# fly---->fli
# flying---->fli
# flew---->flew
# flown---->flown
# write---->write
# writing---->write
# wrote---->wrote
# written---->written
# writes---->write
# read---->read
# reading---->read
# reads---->read
# drink---->drink
# drinking---->drink
# drank---->drank
# drunk---->drunk
# drinks---->drink
# sleep---->sleep
# sleeping---->sleep
# slept---->slept
# sleeps---->sleep
# speak---->speak
# speaking---->speak
# spoke---->spoke
# spoken---->spoken
# speaks---->speak
# break---->break
# breaking---->break
# broke---->broke
# broken---->broken
# breaks---->break
# buy---->buy
# buying---->buy
# bought---->bought
# buys---->buy
# sell---->sell
# selling---->sell
# sold---->sold
# sells---->sell
# know---->know
# knowing---->know
# knew---->knew
# known---->known
# knows---->know
# think---->think
# thinking---->think
# thought---->thought
# thinks---->think
# swim---->swim
# swimming---->swim
# swam---->swam
# swum---->swum
# swims---->swim
# build---->build
# building---->build
# built---->built
# builds---->build
# sing---->sing
# singing---->sing
# sang---->sang
# sung---->sung
# sings---->sing
# teach---->teach
# teaching---->teach
# taught---->taught
# teaches---->teach
# take---->take
# taking---->take
# took---->took
# taken---->taken
# takes---->take

# %%
steaming.stem("Congratulation")
# Out:
# 'congratul'

# %%
steaming.stem("Conference")
# Out:
# 'confer'

# %%
steaming.stem("Sitting")
# Out:
# 'sit'

# %%
# Regexpstemmer class


# ✅ Definition of RegexpStemmer Class
# The RegexpStemmer is a class in the NLTK library that performs stemming based on custom regular expression (regex) rules you define. Unlike rule-based stemmers like Porter, this stemmer allows you to create your own patterns to strip suffixes or prefixes by matching regex patterns.

# 🔍 What is RegexpStemmer?
# It removes the longest matching suffix defined by your regex from the word.

# You provide a regex pattern describing which suffixes to remove.

# Useful when you want custom, lightweight stemming or suffix removal.



from nltk.stem import RegexpStemmer

# %%
Reg_stemmer = RegexpStemmer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 Reg_stemmer = RegexpStemmer()
#
# TypeError: RegexpStemmer.__init__() missing 1 required positional argument: 'regexp'
