# %%
# part of speech tags
"The Ajanta and Ellora caves in Maharashtra are world-famous for their ancient rock-cut architecture and beautiful sculptures. The Gateway of India in Mumbai is a historic monument that attracts thousands of tourists every day. Lonavala and Khandala, with their lush green valleys, are perfect hill stations for nature lovers. The Godavari River, also called the Dakshin Ganga, flows through Nashik, adding beauty to the city. Sanjay Gandhi National Park in Mumbai is a green oasis that offers peace and wildlife experiences. The Shree Siddhivinayak Temple in Mumbai is a major spiritual destination visited by devotees from all over the country. Mahabaleshwar, known for its strawberry farms and scenic viewpoints, is another jewel in Maharashtra’s crown."
# Out:
# 'The Ajanta and Ellora caves in Maharashtra are world-famous for their ancient rock-cut architecture and beautiful sculptures. The Gateway of India in Mumbai is a historic monument that attracts thousands of tourists every day. Lonavala and Khandala, with their lush green valleys, are perfect hill stations for nature lovers. The Godavari River, also called the Dakshin Ganga, flows through Nashik, adding beauty to the city. Sanjay Gandhi National Park in Mumbai is a green oasis that offers peace and wildlife experiences. The Shree Siddhivinayak Temple in Mumbai is a major spiritual destination visited by devotees from all over the country. Mahabaleshwar, known for its strawberry farms and scenic viewpoints, is another jewel in Maharashtra’s crown.'

# %%
# Your paragraph
paragraph = """Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema. In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil. He is a former Rajya Sabha Member of Parliament.[5][6] He is the recipient of three National Film Awards and four Filmfare Awards. In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.[9]

Chakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.[16]

Chakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.[17][18] He also started the production house Paparatzy Productions.[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.[4].."""

# %%
paragraph
# Out:
# "Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema. In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil. He is a former Rajya Sabha Member of Parliament.[5][6] He is the recipient of three National Film Awards and four Filmfare Awards. In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.[9]\n\nChakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.[16]\n\nChakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.[17][18] He also started the production house Paparatzy Productions.[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.[4].."

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')  # <-- Important
nltk.download('averaged_perceptron_tagger_eng')  # <-- For new versions
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
stop_words =set(stopwords.words("english"))

# %%
nltk.sent_tokenize(paragraph)
# Out:
# ['Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema.',
#  'In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil.',
#  'He is a former Rajya Sabha Member of Parliament.',
#  '[5][6] He is the recipient of three National Film Awards and four Filmfare Awards.',
#  'In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.',
#  "[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.",
#  '[9]\n\nChakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.',
#  '[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.',
#  '[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.',
#  "[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.",
#  '[16]\n\nChakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.',
#  '[17][18] He also started the production house Paparatzy Productions.',
#  '[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).',
#  '[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.',
#  '[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.',
#  "[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.",
#  '[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.',
#  '[4]..']

# %%
sentenco = nltk.sent_tokenize(paragraph)

# %%
sentenco
# Out:
# ['Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema.',
#  'In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil.',
#  'He is a former Rajya Sabha Member of Parliament.',
#  '[5][6] He is the recipient of three National Film Awards and four Filmfare Awards.',
#  'In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.',
#  "[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.",
#  '[9]\n\nChakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.',
#  '[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.',
#  '[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.',
#  "[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.",
#  '[16]\n\nChakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.',
#  '[17][18] He also started the production house Paparatzy Productions.',
#  '[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).',
#  '[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.',
#  '[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.',
#  "[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.",
#  '[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.',
#  '[4]..']

# %%
stop_words = set(stopwords.words('english'))

# %%
# Process each sentence
for i in range(len(sentenco)):
    words = word_tokenize(sentenco[i])
    words = [word for word in words if word.lower() not in set(stopwords.words('english'))]
    #words = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Mithun', 'NNP'), ('Chakraborty', 'NNP'), ('(', '('), ('born', 'VBN'), ('Gouranga', 'NNP'), ('Chakraborty', 'NNP'), (';', ':'), ('16', 'CD'), ('June', 'NNP'), ('1950', 'CD'), (')', ')'), ('Indian', 'JJ'), ('actor', 'NN'), (',', ','), ('film', 'NN'), ('producer', 'NN'), (',', ','), ('screenwriter', 'NN'), (',', ','), ('entrepreneur', 'NN'), ('politician', 'NN'), ('predominantly', 'RB'), ('works', 'VBZ'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('cinema', 'NN'), ('.', '.')]
# [('career', 'NN'), ('spanning', 'VBG'), ('five', 'CD'), ('decades', 'NNS'), (',', ','), ('done', 'VBN'), ('350', 'CD'), ('films', 'NNS'), (',', ','), ('mostly', 'RB'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('languages', 'VBZ'), (',', ','), ('Odia', 'NNP'), (',', ','), ('Telugu', 'NNP'), (',', ','), ('Kannada', 'NNP'), (',', ','), ('Punjabi', 'NNP'), ('Tamil', 'NNP'), ('.', '.')]
# [('former', 'JJ'), ('Rajya', 'NNP'), ('Sabha', 'NNP'), ('Member', 'NNP'), ('Parliament', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('5', 'CD'), (']', 'JJ'), ('[', '$'), ('6', 'CD'), (']', 'NNP'), ('recipient', 'NN'), ('three', 'CD'), ('National', 'NNP'), ('Film', 'NNP'), ('Awards', 'NNP'), ('four', 'CD'), ('Filmfare', 'NNP'), ('Awards', 'NNP'), ('.', '.')]
# [('January', 'NNP'), ('2024', 'CD'), (',', ','), ('Chakraborty', 'NNP'), ('awarded', 'VBD'), ('Padma', 'NNP'), ('Bhushan', 'NNP'), (',', ','), ('third-highest', 'JJ'), ('civilian', 'JJ'), ('honour', 'NN'), ('Government', 'NNP'), ('India', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('7', 'CD'), (']', 'JJ'), ('[', '$'), ('8', 'CD'), (']', 'NNP'), ('also', 'RB'), ('awarded', 'VBD'), ('India', 'NNP'), ("'s", 'POS'), ('highest', 'JJS'), ('accolade', 'NN'), ('field', 'NN'), ('cinema', 'NN'), (',', ','), ('Dadasaheb', 'NNP'), ('Phalke', 'NNP'), ('Award', 'NNP'), ('year', 'NN'), ('2022', 'CD'), (',', ','), ('whose', 'WP$'), ('announcement', 'NN'), ('came', 'VBD'), ('Union', 'NNP'), ('Ministry', 'NNP'), ('Information', 'NNP'), ('Broadcasting', 'NNP'), ('September', 'NNP'), ('2024', 'CD'), ('.', '.')]
# [('[', 'RB'), ('9', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('made', 'VBD'), ('acting', 'VBG'), ('debut', 'JJ'), ('art', 'NN'), ('house', 'NN'), ('drama', 'NN'), ('Mrigayaa', 'NNP'), ('(', '('), ('1976', 'CD'), (')', ')'), (',', ','), ('directed', 'VBD'), ('Mrinal', 'NNP'), ('Sen', 'NNP'), (',', ','), ('first', 'JJ'), ('National', 'NNP'), ('Film', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Actor', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('10', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('gained', 'VBD'), ('greater', 'JJR'), ('fame', 'NN'), ('1982', 'CD'), ('film', 'NN'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('major', 'JJ'), ('box', 'NN'), ('office', 'NN'), ('success', 'NN'), ('India', 'NNP'), ('Soviet', 'NNP'), ('Union', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('11', 'CD'), (']', 'JJ'), ('Besides', 'NNP'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('also', 'RB'), ('gained', 'VBD'), ('recognition', 'NN'), ('many', 'JJ'), ('performances', 'NNS'), ('lead', 'VBP'), ('character', 'NN'), ('artist', 'NN'), ('.', '.')]
# [('[', 'RB'), ('12', 'CD'), (']', 'JJ'), ('[', '$'), ('13', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('14', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('15', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ("'s", 'POS'), ('performance', 'NN'), ('Agneepath', 'NNP'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Supporting', 'VBG'), ('Actor', 'NNP'), ('1990', 'CD'), ('.', '.')]
# [('[', 'RB'), ('16', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('owns', 'VBZ'), ('Monarch', 'NNP'), ('Group', 'NNP'), (',', ','), ('interests', 'NNS'), ('hospitality', 'VBP'), ('educational', 'JJ'), ('sectors', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('17', 'CD'), (']', 'JJ'), ('[', '$'), ('18', 'CD'), (']', 'NNP'), ('also', 'RB'), ('started', 'VBD'), ('production', 'NN'), ('house', 'NN'), ('Paparatzy', 'NNP'), ('Productions', 'NNPS'), ('.', '.')]
# [('[', 'RB'), ('19', 'CD'), (']', 'JJ'), ('1992', 'CD'), (',', ','), (',', ','), ('along', 'IN'), ('Dilip', 'NNP'), ('Kumar', 'NNP'), ('Sunil', 'NNP'), ('Dutt', 'NNP'), (',', ','), ('set', 'VBD'), ('trust', 'NN'), ('help', 'NN'), ('actors', 'NNS'), ('need', 'VBP'), ('assistance', 'NN'), ('called', 'VBN'), ('Cine', 'NNP'), ('&', 'CC'), ('T.V', 'NNP'), ('Artistes', 'NNP'), ('Association', 'NNP'), ('(', '('), ('CINTAA', 'NNP'), (')', ')'), ('.', '.')]
# [('[', 'RB'), ('20', 'CD'), (']', 'NNS'), ('also', 'RB'), ('Chairperson', 'NNP'), ('Film', 'NNP'), ('Studios', 'NNP'), ('Setting', 'NNP'), ('&', 'CC'), ('Allied', 'NNP'), ('Mazdoor', 'NNP'), ('Union', 'NNP'), (',', ','), ('protects', 'VBZ'), ('welfare', 'JJ'), ('cinema', 'JJ'), ('workers', 'NNS'), ('resolves', 'NNS'), ('demands', 'NNS'), ('problems', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('21', 'CD'), (']', 'JJ'), ('[', '$'), ('22', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('23', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('24', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('25', 'CD'), (']', 'JJ'), ('television', 'NN'), ('show', 'NN'), ('Dance', 'NNP'), ('India', 'NNP'), ('Dance', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('Grand', 'NNP'), ('Master', 'NNP'), (',', ','), ('also', 'RB'), ('entered', 'VBD'), ('Limca', 'NNP'), ('Book', 'NNP'), ('Records', 'NNP'), ('Guinness', 'NNP'), ('World', 'NNP'), ('Records', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('26', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('played', 'VBD'), ('crucial', 'JJ'), ('mediating', 'NN'), ('role', 'NN'), ('Pranab', 'NNP'), ('Mukherjee', 'NNP'), ('Indian', 'NNP'), ('National', 'NNP'), ('Congress', 'NNP'), ('Mamata', 'NNP'), ('Banerjee', 'NNP'), (',', ','), ('winning', 'VBG'), ('Mukherjee', 'NNP'), ('support', 'NN'), ('Banerjee', 'NNP'), ("'s", 'POS'), ('party', 'NN'), (',', ','), ('India', 'NNP'), ('Trinamool', 'NNP'), ('Congress', 'NNP'), (',', ','), ('2012', 'CD'), ('Indian', 'JJ'), ('presidential', 'JJ'), ('election', 'NN'), ('.', '.')]
# [('[', 'RB'), ('27', 'CD'), (']', 'NNS'), ('joined', 'VBD'), ('Bharatiya', 'NNP'), ('Janata', 'NNP'), ('Party', 'NNP'), ('(', '('), ('BJP', 'NNP'), (')', ')'), ('7', 'CD'), ('March', 'NNP'), ('2021', 'CD'), (',', ','), ('ahead', 'RB'), ('2021', 'CD'), ('West', 'NNP'), ('Bengal', 'NNP'), ('Legislative', 'NNP'), ('Assembly', 'NNP'), ('election', 'NN'), ('.', '.')]
# [('[', 'RB'), ('4', 'CD'), (']', 'NNS'), ('..', 'VBP')]

# %%
# Process each sentence
for i in range(len(sentenco)):
    words = word_tokenize(sentenco[i])
    words = [word for word in words if word.lower() not in set(stopwords.words('english'))]
    #words = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    pos_tag = nltk.pos_tag(words)
    print(f"sentenco {i+1} POS Tags:",pos_tag)
# Out:
# sentenco 1 POS Tags: [('Mithun', 'NNP'), ('Chakraborty', 'NNP'), ('(', '('), ('born', 'VBN'), ('Gouranga', 'NNP'), ('Chakraborty', 'NNP'), (';', ':'), ('16', 'CD'), ('June', 'NNP'), ('1950', 'CD'), (')', ')'), ('Indian', 'JJ'), ('actor', 'NN'), (',', ','), ('film', 'NN'), ('producer', 'NN'), (',', ','), ('screenwriter', 'NN'), (',', ','), ('entrepreneur', 'NN'), ('politician', 'NN'), ('predominantly', 'RB'), ('works', 'VBZ'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('cinema', 'NN'), ('.', '.')]
# sentenco 2 POS Tags: [('career', 'NN'), ('spanning', 'VBG'), ('five', 'CD'), ('decades', 'NNS'), (',', ','), ('done', 'VBN'), ('350', 'CD'), ('films', 'NNS'), (',', ','), ('mostly', 'RB'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('languages', 'VBZ'), (',', ','), ('Odia', 'NNP'), (',', ','), ('Telugu', 'NNP'), (',', ','), ('Kannada', 'NNP'), (',', ','), ('Punjabi', 'NNP'), ('Tamil', 'NNP'), ('.', '.')]
# sentenco 3 POS Tags: [('former', 'JJ'), ('Rajya', 'NNP'), ('Sabha', 'NNP'), ('Member', 'NNP'), ('Parliament', 'NNP'), ('.', '.')]
# sentenco 4 POS Tags: [('[', 'RB'), ('5', 'CD'), (']', 'JJ'), ('[', '$'), ('6', 'CD'), (']', 'NNP'), ('recipient', 'NN'), ('three', 'CD'), ('National', 'NNP'), ('Film', 'NNP'), ('Awards', 'NNP'), ('four', 'CD'), ('Filmfare', 'NNP'), ('Awards', 'NNP'), ('.', '.')]
# sentenco 5 POS Tags: [('January', 'NNP'), ('2024', 'CD'), (',', ','), ('Chakraborty', 'NNP'), ('awarded', 'VBD'), ('Padma', 'NNP'), ('Bhushan', 'NNP'), (',', ','), ('third-highest', 'JJ'), ('civilian', 'JJ'), ('honour', 'NN'), ('Government', 'NNP'), ('India', 'NNP'), ('.', '.')]
# sentenco 6 POS Tags: [('[', 'RB'), ('7', 'CD'), (']', 'JJ'), ('[', '$'), ('8', 'CD'), (']', 'NNP'), ('also', 'RB'), ('awarded', 'VBD'), ('India', 'NNP'), ("'s", 'POS'), ('highest', 'JJS'), ('accolade', 'NN'), ('field', 'NN'), ('cinema', 'NN'), (',', ','), ('Dadasaheb', 'NNP'), ('Phalke', 'NNP'), ('Award', 'NNP'), ('year', 'NN'), ('2022', 'CD'), (',', ','), ('whose', 'WP$'), ('announcement', 'NN'), ('came', 'VBD'), ('Union', 'NNP'), ('Ministry', 'NNP'), ('Information', 'NNP'), ('Broadcasting', 'NNP'), ('September', 'NNP'), ('2024', 'CD'), ('.', '.')]
# sentenco 7 POS Tags: [('[', 'RB'), ('9', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('made', 'VBD'), ('acting', 'VBG'), ('debut', 'JJ'), ('art', 'NN'), ('house', 'NN'), ('drama', 'NN'), ('Mrigayaa', 'NNP'), ('(', '('), ('1976', 'CD'), (')', ')'), (',', ','), ('directed', 'VBD'), ('Mrinal', 'NNP'), ('Sen', 'NNP'), (',', ','), ('first', 'JJ'), ('National', 'NNP'), ('Film', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Actor', 'NNP'), ('.', '.')]
# sentenco 8 POS Tags: [('[', 'RB'), ('10', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('gained', 'VBD'), ('greater', 'JJR'), ('fame', 'NN'), ('1982', 'CD'), ('film', 'NN'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('major', 'JJ'), ('box', 'NN'), ('office', 'NN'), ('success', 'NN'), ('India', 'NNP'), ('Soviet', 'NNP'), ('Union', 'NNP'), ('.', '.')]
# sentenco 9 POS Tags: [('[', 'RB'), ('11', 'CD'), (']', 'JJ'), ('Besides', 'NNP'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('also', 'RB'), ('gained', 'VBD'), ('recognition', 'NN'), ('many', 'JJ'), ('performances', 'NNS'), ('lead', 'VBP'), ('character', 'NN'), ('artist', 'NN'), ('.', '.')]
# sentenco 10 POS Tags: [('[', 'RB'), ('12', 'CD'), (']', 'JJ'), ('[', '$'), ('13', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('14', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('15', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ("'s", 'POS'), ('performance', 'NN'), ('Agneepath', 'NNP'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Supporting', 'VBG'), ('Actor', 'NNP'), ('1990', 'CD'), ('.', '.')]
# sentenco 11 POS Tags: [('[', 'RB'), ('16', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('owns', 'VBZ'), ('Monarch', 'NNP'), ('Group', 'NNP'), (',', ','), ('interests', 'NNS'), ('hospitality', 'VBP'), ('educational', 'JJ'), ('sectors', 'NNS'), ('.', '.')]
# sentenco 12 POS Tags: [('[', 'RB'), ('17', 'CD'), (']', 'JJ'), ('[', '$'), ('18', 'CD'), (']', 'NNP'), ('also', 'RB'), ('started', 'VBD'), ('production', 'NN'), ('house', 'NN'), ('Paparatzy', 'NNP'), ('Productions', 'NNPS'), ('.', '.')]
# sentenco 13 POS Tags: [('[', 'RB'), ('19', 'CD'), (']', 'JJ'), ('1992', 'CD'), (',', ','), (',', ','), ('along', 'IN'), ('Dilip', 'NNP'), ('Kumar', 'NNP'), ('Sunil', 'NNP'), ('Dutt', 'NNP'), (',', ','), ('set', 'VBD'), ('trust', 'NN'), ('help', 'NN'), ('actors', 'NNS'), ('need', 'VBP'), ('assistance', 'NN'), ('called', 'VBN'), ('Cine', 'NNP'), ('&', 'CC'), ('T.V', 'NNP'), ('Artistes', 'NNP'), ('Association', 'NNP'), ('(', '('), ('CINTAA', 'NNP'), (')', ')'), ('.', '.')]
# sentenco 14 POS Tags: [('[', 'RB'), ('20', 'CD'), (']', 'NNS'), ('also', 'RB'), ('Chairperson', 'NNP'), ('Film', 'NNP'), ('Studios', 'NNP'), ('Setting', 'NNP'), ('&', 'CC'), ('Allied', 'NNP'), ('Mazdoor', 'NNP'), ('Union', 'NNP'), (',', ','), ('protects', 'VBZ'), ('welfare', 'JJ'), ('cinema', 'JJ'), ('workers', 'NNS'), ('resolves', 'NNS'), ('demands', 'NNS'), ('problems', 'NNS'), ('.', '.')]
# sentenco 15 POS Tags: [('[', 'RB'), ('21', 'CD'), (']', 'JJ'), ('[', '$'), ('22', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('23', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('24', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('25', 'CD'), (']', 'JJ'), ('television', 'NN'), ('show', 'NN'), ('Dance', 'NNP'), ('India', 'NNP'), ('Dance', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('Grand', 'NNP'), ('Master', 'NNP'), (',', ','), ('also', 'RB'), ('entered', 'VBD'), ('Limca', 'NNP'), ('Book', 'NNP'), ('Records', 'NNP'), ('Guinness', 'NNP'), ('World', 'NNP'), ('Records', 'NNP'), ('.', '.')]
# sentenco 16 POS Tags: [('[', 'RB'), ('26', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('played', 'VBD'), ('crucial', 'JJ'), ('mediating', 'NN'), ('role', 'NN'), ('Pranab', 'NNP'), ('Mukherjee', 'NNP'), ('Indian', 'NNP'), ('National', 'NNP'), ('Congress', 'NNP'), ('Mamata', 'NNP'), ('Banerjee', 'NNP'), (',', ','), ('winning', 'VBG'), ('Mukherjee', 'NNP'), ('support', 'NN'), ('Banerjee', 'NNP'), ("'s", 'POS'), ('party', 'NN'), (',', ','), ('India', 'NNP'), ('Trinamool', 'NNP'), ('Congress', 'NNP'), (',', ','), ('2012', 'CD'), ('Indian', 'JJ'), ('presidential', 'JJ'), ('election', 'NN'), ('.', '.')]
# sentenco 17 POS Tags: [('[', 'RB'), ('27', 'CD'), (']', 'NNS'), ('joined', 'VBD'), ('Bharatiya', 'NNP'), ('Janata', 'NNP'), ('Party', 'NNP'), ('(', '('), ('BJP', 'NNP'), (')', ')'), ('7', 'CD'), ('March', 'NNP'), ('2021', 'CD'), (',', ','), ('ahead', 'RB'), ('2021', 'CD'), ('West', 'NNP'), ('Bengal', 'NNP'), ('Legislative', 'NNP'), ('Assembly', 'NNP'), ('election', 'NN'), ('.', '.')]
# sentenco 18 POS Tags: [('[', 'RB'), ('4', 'CD'), (']', 'NNS'), ('..', 'VBP')]

# %%
# Process each sentence
for i in range(len(sentenco)):
    words = word_tokenize(sentenco[i])
    words = [word for word in words if word.lower() not in set(stopwords.words('english'))]
    #words = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Mithun', 'NNP'), ('Chakraborty', 'NNP'), ('(', '('), ('born', 'VBN'), ('Gouranga', 'NNP'), ('Chakraborty', 'NNP'), (';', ':'), ('16', 'CD'), ('June', 'NNP'), ('1950', 'CD'), (')', ')'), ('Indian', 'JJ'), ('actor', 'NN'), (',', ','), ('film', 'NN'), ('producer', 'NN'), (',', ','), ('screenwriter', 'NN'), (',', ','), ('entrepreneur', 'NN'), ('politician', 'NN'), ('predominantly', 'RB'), ('works', 'VBZ'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('cinema', 'NN'), ('.', '.')]
# [('career', 'NN'), ('spanning', 'VBG'), ('five', 'CD'), ('decades', 'NNS'), (',', ','), ('done', 'VBN'), ('350', 'CD'), ('films', 'NNS'), (',', ','), ('mostly', 'RB'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('languages', 'VBZ'), (',', ','), ('Odia', 'NNP'), (',', ','), ('Telugu', 'NNP'), (',', ','), ('Kannada', 'NNP'), (',', ','), ('Punjabi', 'NNP'), ('Tamil', 'NNP'), ('.', '.')]
# [('former', 'JJ'), ('Rajya', 'NNP'), ('Sabha', 'NNP'), ('Member', 'NNP'), ('Parliament', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('5', 'CD'), (']', 'JJ'), ('[', '$'), ('6', 'CD'), (']', 'NNP'), ('recipient', 'NN'), ('three', 'CD'), ('National', 'NNP'), ('Film', 'NNP'), ('Awards', 'NNP'), ('four', 'CD'), ('Filmfare', 'NNP'), ('Awards', 'NNP'), ('.', '.')]
# [('January', 'NNP'), ('2024', 'CD'), (',', ','), ('Chakraborty', 'NNP'), ('awarded', 'VBD'), ('Padma', 'NNP'), ('Bhushan', 'NNP'), (',', ','), ('third-highest', 'JJ'), ('civilian', 'JJ'), ('honour', 'NN'), ('Government', 'NNP'), ('India', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('7', 'CD'), (']', 'JJ'), ('[', '$'), ('8', 'CD'), (']', 'NNP'), ('also', 'RB'), ('awarded', 'VBD'), ('India', 'NNP'), ("'s", 'POS'), ('highest', 'JJS'), ('accolade', 'NN'), ('field', 'NN'), ('cinema', 'NN'), (',', ','), ('Dadasaheb', 'NNP'), ('Phalke', 'NNP'), ('Award', 'NNP'), ('year', 'NN'), ('2022', 'CD'), (',', ','), ('whose', 'WP$'), ('announcement', 'NN'), ('came', 'VBD'), ('Union', 'NNP'), ('Ministry', 'NNP'), ('Information', 'NNP'), ('Broadcasting', 'NNP'), ('September', 'NNP'), ('2024', 'CD'), ('.', '.')]
# [('[', 'RB'), ('9', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('made', 'VBD'), ('acting', 'VBG'), ('debut', 'JJ'), ('art', 'NN'), ('house', 'NN'), ('drama', 'NN'), ('Mrigayaa', 'NNP'), ('(', '('), ('1976', 'CD'), (')', ')'), (',', ','), ('directed', 'VBD'), ('Mrinal', 'NNP'), ('Sen', 'NNP'), (',', ','), ('first', 'JJ'), ('National', 'NNP'), ('Film', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Actor', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('10', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('gained', 'VBD'), ('greater', 'JJR'), ('fame', 'NN'), ('1982', 'CD'), ('film', 'NN'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('major', 'JJ'), ('box', 'NN'), ('office', 'NN'), ('success', 'NN'), ('India', 'NNP'), ('Soviet', 'NNP'), ('Union', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('11', 'CD'), (']', 'JJ'), ('Besides', 'NNP'), ('Disco', 'NNP'), ('Dancer', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('also', 'RB'), ('gained', 'VBD'), ('recognition', 'NN'), ('many', 'JJ'), ('performances', 'NNS'), ('lead', 'VBP'), ('character', 'NN'), ('artist', 'NN'), ('.', '.')]
# [('[', 'RB'), ('12', 'CD'), (']', 'JJ'), ('[', '$'), ('13', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('14', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('15', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ("'s", 'POS'), ('performance', 'NN'), ('Agneepath', 'NNP'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Supporting', 'VBG'), ('Actor', 'NNP'), ('1990', 'CD'), ('.', '.')]
# [('[', 'RB'), ('16', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('owns', 'VBZ'), ('Monarch', 'NNP'), ('Group', 'NNP'), (',', ','), ('interests', 'NNS'), ('hospitality', 'VBP'), ('educational', 'JJ'), ('sectors', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('17', 'CD'), (']', 'JJ'), ('[', '$'), ('18', 'CD'), (']', 'NNP'), ('also', 'RB'), ('started', 'VBD'), ('production', 'NN'), ('house', 'NN'), ('Paparatzy', 'NNP'), ('Productions', 'NNPS'), ('.', '.')]
# [('[', 'RB'), ('19', 'CD'), (']', 'JJ'), ('1992', 'CD'), (',', ','), (',', ','), ('along', 'IN'), ('Dilip', 'NNP'), ('Kumar', 'NNP'), ('Sunil', 'NNP'), ('Dutt', 'NNP'), (',', ','), ('set', 'VBD'), ('trust', 'NN'), ('help', 'NN'), ('actors', 'NNS'), ('need', 'VBP'), ('assistance', 'NN'), ('called', 'VBN'), ('Cine', 'NNP'), ('&', 'CC'), ('T.V', 'NNP'), ('Artistes', 'NNP'), ('Association', 'NNP'), ('(', '('), ('CINTAA', 'NNP'), (')', ')'), ('.', '.')]
# [('[', 'RB'), ('20', 'CD'), (']', 'NNS'), ('also', 'RB'), ('Chairperson', 'NNP'), ('Film', 'NNP'), ('Studios', 'NNP'), ('Setting', 'NNP'), ('&', 'CC'), ('Allied', 'NNP'), ('Mazdoor', 'NNP'), ('Union', 'NNP'), (',', ','), ('protects', 'VBZ'), ('welfare', 'JJ'), ('cinema', 'JJ'), ('workers', 'NNS'), ('resolves', 'NNS'), ('demands', 'NNS'), ('problems', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('21', 'CD'), (']', 'JJ'), ('[', '$'), ('22', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('23', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('24', 'CD'), (']', 'NNP'), ('[', 'VBD'), ('25', 'CD'), (']', 'JJ'), ('television', 'NN'), ('show', 'NN'), ('Dance', 'NNP'), ('India', 'NNP'), ('Dance', 'NNP'), (',', ','), ('Chakraborty', 'NNP'), ('Grand', 'NNP'), ('Master', 'NNP'), (',', ','), ('also', 'RB'), ('entered', 'VBD'), ('Limca', 'NNP'), ('Book', 'NNP'), ('Records', 'NNP'), ('Guinness', 'NNP'), ('World', 'NNP'), ('Records', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('26', 'CD'), (']', 'NNP'), ('Chakraborty', 'NNP'), ('played', 'VBD'), ('crucial', 'JJ'), ('mediating', 'NN'), ('role', 'NN'), ('Pranab', 'NNP'), ('Mukherjee', 'NNP'), ('Indian', 'NNP'), ('National', 'NNP'), ('Congress', 'NNP'), ('Mamata', 'NNP'), ('Banerjee', 'NNP'), (',', ','), ('winning', 'VBG'), ('Mukherjee', 'NNP'), ('support', 'NN'), ('Banerjee', 'NNP'), ("'s", 'POS'), ('party', 'NN'), (',', ','), ('India', 'NNP'), ('Trinamool', 'NNP'), ('Congress', 'NNP'), (',', ','), ('2012', 'CD'), ('Indian', 'JJ'), ('presidential', 'JJ'), ('election', 'NN'), ('.', '.')]
# [('[', 'RB'), ('27', 'CD'), (']', 'NNS'), ('joined', 'VBD'), ('Bharatiya', 'NNP'), ('Janata', 'NNP'), ('Party', 'NNP'), ('(', '('), ('BJP', 'NNP'), (')', ')'), ('7', 'CD'), ('March', 'NNP'), ('2021', 'CD'), (',', ','), ('ahead', 'RB'), ('2021', 'CD'), ('West', 'NNP'), ('Bengal', 'NNP'), ('Legislative', 'NNP'), ('Assembly', 'NNP'), ('election', 'NN'), ('.', '.')]
# [('[', 'RB'), ('4', 'CD'), (']', 'NNS'), ('..', 'VBP')]

# %%
# Loop through each sentence
for i in range(len(sentenco)):
    words = word_tokenize(sentenco[i])
    words = [word for word in words if word.lower() not in stop_words and word.isalnum()]  # Remove stopwords & punctuation
    pos_tag = nltk.pos_tag(words)
    print(f"Sentence {i+1} POS Tags:", pos_tag)
# Out:
# Sentence 1 POS Tags: [('Mithun', 'NNP'), ('Chakraborty', 'NNP'), ('born', 'VBD'), ('Gouranga', 'NNP'), ('Chakraborty', 'NNP'), ('16', 'CD'), ('June', 'NNP'), ('1950', 'CD'), ('Indian', 'NNP'), ('actor', 'NN'), ('film', 'NN'), ('producer', 'NN'), ('screenwriter', 'NN'), ('entrepreneur', 'NN'), ('politician', 'NN'), ('predominantly', 'RB'), ('works', 'VBZ'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('cinema', 'NN')]
# Sentence 2 POS Tags: [('career', 'NN'), ('spanning', 'VBG'), ('five', 'CD'), ('decades', 'NNS'), ('done', 'VBN'), ('350', 'CD'), ('films', 'NNS'), ('mostly', 'RB'), ('Hindi', 'NNP'), ('Bengali', 'NNP'), ('languages', 'VBZ'), ('Odia', 'NNP'), ('Telugu', 'NNP'), ('Kannada', 'NNP'), ('Punjabi', 'NNP'), ('Tamil', 'NNP')]
# Sentence 3 POS Tags: [('former', 'JJ'), ('Rajya', 'NNP'), ('Sabha', 'NNP'), ('Member', 'NNP'), ('Parliament', 'NNP')]
# Sentence 4 POS Tags: [('5', 'CD'), ('6', 'CD'), ('recipient', 'NN'), ('three', 'CD'), ('National', 'NNP'), ('Film', 'NNP'), ('Awards', 'NNP'), ('four', 'CD'), ('Filmfare', 'NNP'), ('Awards', 'NNP')]
# Sentence 5 POS Tags: [('January', 'NNP'), ('2024', 'CD'), ('Chakraborty', 'NNP'), ('awarded', 'VBD'), ('Padma', 'NNP'), ('Bhushan', 'NNP'), ('civilian', 'JJ'), ('honour', 'JJ'), ('Government', 'NNP'), ('India', 'NNP')]
# Sentence 6 POS Tags: [('7', 'CD'), ('8', 'CD'), ('also', 'RB'), ('awarded', 'VBD'), ('India', 'NNP'), ('highest', 'JJS'), ('accolade', 'JJ'), ('field', 'NN'), ('cinema', 'NN'), ('Dadasaheb', 'NNP'), ('Phalke', 'NNP'), ('Award', 'NNP'), ('year', 'NN'), ('2022', 'CD'), ('whose', 'WP$'), ('announcement', 'NN'), ('came', 'VBD'), ('Union', 'NNP'), ('Ministry', 'NNP'), ('Information', 'NNP'), ('Broadcasting', 'NNP'), ('September', 'NNP'), ('2024', 'CD')]
# Sentence 7 POS Tags: [('9', 'CD'), ('Chakraborty', 'NNP'), ('made', 'VBD'), ('acting', 'VBG'), ('debut', 'JJ'), ('art', 'NN'), ('house', 'NN'), ('drama', 'NN'), ('Mrigayaa', 'NNP'), ('1976', 'CD'), ('directed', 'VBD'), ('Mrinal', 'NNP'), ('Sen', 'NNP'), ('first', 'JJ'), ('National', 'NNP'), ('Film', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Actor', 'NN')]
# Sentence 8 POS Tags: [('10', 'CD'), ('Chakraborty', 'NN'), ('gained', 'VBD'), ('greater', 'JJR'), ('fame', 'NN'), ('1982', 'CD'), ('film', 'NN'), ('Disco', 'NNP'), ('Dancer', 'NNP'), ('major', 'JJ'), ('box', 'NN'), ('office', 'NN'), ('success', 'NN'), ('India', 'NNP'), ('Soviet', 'NNP'), ('Union', 'NNP')]
# Sentence 9 POS Tags: [('11', 'CD'), ('Besides', 'NNP'), ('Disco', 'NNP'), ('Dancer', 'NNP'), ('Chakraborty', 'NNP'), ('also', 'RB'), ('gained', 'VBD'), ('recognition', 'NN'), ('many', 'JJ'), ('performances', 'NNS'), ('lead', 'VBP'), ('character', 'NN'), ('artist', 'NN')]
# Sentence 10 POS Tags: [('12', 'CD'), ('13', 'CD'), ('14', 'CD'), ('15', 'CD'), ('Chakraborty', 'NNP'), ('performance', 'NN'), ('Agneepath', 'NNP'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Supporting', 'VBG'), ('Actor', 'NN'), ('1990', 'CD')]
# Sentence 11 POS Tags: [('16', 'CD'), ('Chakraborty', 'NNP'), ('owns', 'VBZ'), ('Monarch', 'NNP'), ('Group', 'NNP'), ('interests', 'NNS'), ('hospitality', 'VBP'), ('educational', 'JJ'), ('sectors', 'NNS')]
# Sentence 12 POS Tags: [('17', 'CD'), ('18', 'CD'), ('also', 'RB'), ('started', 'VBD'), ('production', 'NN'), ('house', 'NN'), ('Paparatzy', 'NNP'), ('Productions', 'NNP')]
# Sentence 13 POS Tags: [('19', 'CD'), ('1992', 'CD'), ('along', 'IN'), ('Dilip', 'NNP'), ('Kumar', 'NNP'), ('Sunil', 'NNP'), ('Dutt', 'NNP'), ('set', 'VBD'), ('trust', 'NN'), ('help', 'NN'), ('actors', 'NNS'), ('need', 'VBP'), ('assistance', 'NN'), ('called', 'VBN'), ('Cine', 'NNP'), ('Artistes', 'NNP'), ('Association', 'NNP'), ('CINTAA', 'NNP')]
# Sentence 14 POS Tags: [('20', 'CD'), ('also', 'RB'), ('Chairperson', 'NNP'), ('Film', 'NNP'), ('Studios', 'NNP'), ('Setting', 'NNP'), ('Allied', 'NNP'), ('Mazdoor', 'NNP'), ('Union', 'NNP'), ('protects', 'VBZ'), ('welfare', 'JJ'), ('cinema', 'JJ'), ('workers', 'NNS'), ('resolves', 'NNS'), ('demands', 'NNS'), ('problems', 'NNS')]
# Sentence 15 POS Tags: [('21', 'CD'), ('22', 'CD'), ('23', 'CD'), ('24', 'CD'), ('25', 'CD'), ('television', 'NN'), ('show', 'NN'), ('Dance', 'NNP'), ('India', 'NNP'), ('Dance', 'NNP'), ('Chakraborty', 'NNP'), ('Grand', 'NNP'), ('Master', 'NNP'), ('also', 'RB'), ('entered', 'VBD'), ('Limca', 'NNP'), ('Book', 'NNP'), ('Records', 'NNP'), ('Guinness', 'NNP'), ('World', 'NNP'), ('Records', 'NNP')]
# Sentence 16 POS Tags: [('26', 'CD'), ('Chakraborty', 'NNP'), ('played', 'VBD'), ('crucial', 'JJ'), ('mediating', 'NN'), ('role', 'NN'), ('Pranab', 'NNP'), ('Mukherjee', 'NNP'), ('Indian', 'NNP'), ('National', 'NNP'), ('Congress', 'NNP'), ('Mamata', 'NNP'), ('Banerjee', 'NNP'), ('winning', 'VBG'), ('Mukherjee', 'NNP'), ('support', 'NN'), ('Banerjee', 'NNP'), ('party', 'NN'), ('India', 'NNP'), ('Trinamool', 'NNP'), ('Congress', 'NNP'), ('2012', 'CD'), ('Indian', 'NNP'), ('presidential', 'JJ'), ('election', 'NN')]
# Sentence 17 POS Tags: [('27', 'CD'), ('joined', 'VBD'), ('Bharatiya', 'NNP'), ('Janata', 'NNP'), ('Party', 'NNP'), ('BJP', 'NNP'), ('7', 'CD'), ('March', 'NNP'), ('2021', 'CD'), ('ahead', 'RB'), ('2021', 'CD'), ('West', 'NNP'), ('Bengal', 'NNP'), ('Legislative', 'NNP'), ('Assembly', 'NNP'), ('election', 'NN')]
# Sentence 18 POS Tags: [('4', 'CD')]

# %%
"The Ajanta and Ellora caves in Maharashtra are world-famous for their ancient rock-cut architecture and beautiful sculptures".split()
# Out:
# ['The',
#  'Ajanta',
#  'and',
#  'Ellora',
#  'caves',
#  'in',
#  'Maharashtra',
#  'are',
#  'world-famous',
#  'for',
#  'their',
#  'ancient',
#  'rock-cut',
#  'architecture',
#  'and',
#  'beautiful',
#  'sculptures']

# %%
print(nltk.pos_tag( "The Ajanta and Ellora caves in Maharashtra are world-famous for their ancient rock-cut architecture and beautiful sculptures".split()))
# Out:
# [('The', 'DT'), ('Ajanta', 'NNP'), ('and', 'CC'), ('Ellora', 'NNP'), ('caves', 'NNS'), ('in', 'IN'), ('Maharashtra', 'NNP'), ('are', 'VBP'), ('world-famous', 'JJ'), ('for', 'IN'), ('their', 'PRP$'), ('ancient', 'JJ'), ('rock-cut', 'JJ'), ('architecture', 'NN'), ('and', 'CC'), ('beautiful', 'JJ'), ('sculptures', 'NNS')]

# %%
"""Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema. In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil. He is a former Rajya Sabha Member of Parliament.[5][6] He is the recipient of three National Film Awards and four Filmfare Awards. In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.[9]

Chakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.[16]

Chakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.[17][18] He also started the production house Paparatzy Productions.[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.[4]..""".split()
# Out:
# ['Mithun',
#  'Chakraborty',
#  '(born',
#  'Gouranga',
#  'Chakraborty;',
#  '16',
#  'June',
#  '1950)',
#  'is',
#  'an',
#  'Indian',
#  'actor,',
#  'film',
#  'producer,',
#  'screenwriter,',
#  'entrepreneur',
#  'and',
#  'politician',
#  'who',
#  'predominantly',
#  'works',
#  'in',
#  'Hindi',
#  'and',
#  'Bengali',
#  'cinema.',
#  'In',
#  'a',
#  'career',
#  'spanning',
#  'over',
#  'five',
#  'decades,',
#  'he',
#  'has',
#  'done',
#  '350',
#  'films,',
#  'mostly',
#  'in',
#  'Hindi',
#  'and',
#  'Bengali',
#  'languages,',
#  'and',
#  'a',
#  'few',
#  'in',
#  'Odia,',
#  'Telugu,',
#  'Kannada,',
#  'Punjabi',
#  'and',
#  'Tamil.',
#  'He',
#  'is',
#  'a',
#  'former',
#  'Rajya',
#  'Sabha',
#  'Member',
#  'of',
#  'Parliament.[5][6]',
#  'He',
#  'is',
#  'the',
#  'recipient',
#  'of',
#  'three',
#  'National',
#  'Film',
#  'Awards',
#  'and',
#  'four',
#  'Filmfare',
#  'Awards.',
#  'In',
#  'January',
#  '2024,',
#  'Chakraborty',
#  'was',
#  'awarded',
#  'Padma',
#  'Bhushan,',
#  'the',
#  'third-highest',
#  'civilian',
#  'honour',
#  'by',
#  'the',
#  'Government',
#  'of',
#  'India.[7][8]',
#  'He',
#  'was',
#  'also',
#  'awarded',
#  "India's",
#  'highest',
#  'accolade',
#  'in',
#  'the',
#  'field',
#  'of',
#  'cinema,',
#  'the',
#  'Dadasaheb',
#  'Phalke',
#  'Award',
#  'for',
#  'the',
#  'year',
#  '2022,',
#  'whose',
#  'announcement',
#  'came',
#  'from',
#  'the',
#  'Union',
#  'Ministry',
#  'of',
#  'Information',
#  'and',
#  'Broadcasting',
#  'in',
#  'September',
#  '2024.[9]',
#  'Chakraborty',
#  'made',
#  'his',
#  'acting',
#  'debut',
#  'with',
#  'the',
#  'art',
#  'house',
#  'drama',
#  'Mrigayaa',
#  '(1976),',
#  'directed',
#  'by',
#  'Mrinal',
#  'Sen,',
#  'for',
#  'which',
#  'he',
#  'won',
#  'his',
#  'first',
#  'National',
#  'Film',
#  'Award',
#  'for',
#  'Best',
#  'Actor.[10]',
#  'Chakraborty',
#  'gained',
#  'greater',
#  'fame',
#  'with',
#  'the',
#  '1982',
#  'film',
#  'Disco',
#  'Dancer,',
#  'which',
#  'was',
#  'a',
#  'major',
#  'box',
#  'office',
#  'success',
#  'in',
#  'India',
#  'and',
#  'the',
#  'Soviet',
#  'Union.[11]',
#  'Besides',
#  'Disco',
#  'Dancer,',
#  'Chakraborty',
#  'also',
#  'gained',
#  'recognition',
#  'for',
#  'many',
#  'other',
#  'performances',
#  'as',
#  'both',
#  'a',
#  'lead',
#  'and',
#  'character',
#  'artist.[12][13][14][15]',
#  "Chakraborty's",
#  'performance',
#  'in',
#  'Agneepath',
#  'won',
#  'him',
#  'the',
#  'Filmfare',
#  'Award',
#  'for',
#  'Best',
#  'Supporting',
#  'Actor',
#  'in',
#  '1990.[16]',
#  'Chakraborty',
#  'owns',
#  'the',
#  'Monarch',
#  'Group,',
#  'which',
#  'has',
#  'interests',
#  'in',
#  'the',
#  'hospitality',
#  'and',
#  'educational',
#  'sectors.[17][18]',
#  'He',
#  'also',
#  'started',
#  'the',
#  'production',
#  'house',
#  'Paparatzy',
#  'Productions.[19]',
#  'In',
#  '1992,',
#  'he,',
#  'along',
#  'with',
#  'Dilip',
#  'Kumar',
#  'and',
#  'Sunil',
#  'Dutt,',
#  'set',
#  'up',
#  'a',
#  'trust',
#  'to',
#  'help',
#  'actors',
#  'in',
#  'need',
#  'of',
#  'assistance',
#  'called',
#  'Cine',
#  '&',
#  'T.V',
#  'Artistes',
#  'Association',
#  '(CINTAA).[20]',
#  'He',
#  'was',
#  'also',
#  'the',
#  'Chairperson',
#  'of',
#  'Film',
#  'Studios',
#  'Setting',
#  '&',
#  'Allied',
#  'Mazdoor',
#  'Union,',
#  'which',
#  'protects',
#  'the',
#  'welfare',
#  'of',
#  'cinema',
#  'workers',
#  'and',
#  'resolves',
#  'their',
#  'demands',
#  'and',
#  'problems.[21][22][23][24][25]',
#  'The',
#  'television',
#  'show',
#  'Dance',
#  'India',
#  'Dance,',
#  'where',
#  'Chakraborty',
#  'was',
#  'the',
#  'Grand',
#  'Master,',
#  'also',
#  'entered',
#  'in',
#  'the',
#  'Limca',
#  'Book',
#  'of',
#  'Records',
#  'and',
#  'the',
#  'Guinness',
#  'World',
#  'Records.[26]',
#  'Chakraborty',
#  'played',
#  'a',
#  'crucial',
#  'mediating',
#  'role',
#  'between',
#  'Pranab',
#  'Mukherjee',
#  'of',
#  'the',
#  'Indian',
#  'National',
#  'Congress',
#  'and',
#  'Mamata',
#  'Banerjee,',
#  'winning',
#  'Mukherjee',
#  'the',
#  'support',
#  'of',
#  "Banerjee's",
#  'party,',
#  'the',
#  'All',
#  'India',
#  'Trinamool',
#  'Congress,',
#  'in',
#  'the',
#  '2012',
#  'Indian',
#  'presidential',
#  'election.[27]',
#  'He',
#  'joined',
#  'the',
#  'Bharatiya',
#  'Janata',
#  'Party',
#  '(BJP)',
#  'on',
#  '7',
#  'March',
#  '2021,',
#  'ahead',
#  'of',
#  'the',
#  '2021',
#  'West',
#  'Bengal',
#  'Legislative',
#  'Assembly',
#  'election.[4]..']

# %%
print(nltk.pos_tag("""Mithun Chakraborty (born Gouranga Chakraborty; 16 June 1950) is an Indian actor, film producer, screenwriter, entrepreneur and politician who predominantly works in Hindi and Bengali cinema. In a career spanning over five decades, he has done 350 films, mostly in Hindi and Bengali languages, and a few in Odia, Telugu, Kannada, Punjabi and Tamil. He is a former Rajya Sabha Member of Parliament.[5][6] He is the recipient of three National Film Awards and four Filmfare Awards. In January 2024, Chakraborty was awarded Padma Bhushan, the third-highest civilian honour by the Government of India.[7][8] He was also awarded India's highest accolade in the field of cinema, the Dadasaheb Phalke Award for the year 2022, whose announcement came from the Union Ministry of Information and Broadcasting in September 2024.[9]

Chakraborty made his acting debut with the art house drama Mrigayaa (1976), directed by Mrinal Sen, for which he won his first National Film Award for Best Actor.[10] Chakraborty gained greater fame with the 1982 film Disco Dancer, which was a major box office success in India and the Soviet Union.[11] Besides Disco Dancer, Chakraborty also gained recognition for many other performances as both a lead and character artist.[12][13][14][15] Chakraborty's performance in Agneepath won him the Filmfare Award for Best Supporting Actor in 1990.[16]

Chakraborty owns the Monarch Group, which has interests in the hospitality and educational sectors.[17][18] He also started the production house Paparatzy Productions.[19] In 1992, he, along with Dilip Kumar and Sunil Dutt, set up a trust to help actors in need of assistance called Cine & T.V Artistes Association (CINTAA).[20] He was also the Chairperson of Film Studios Setting & Allied Mazdoor Union, which protects the welfare of cinema workers and resolves their demands and problems.[21][22][23][24][25] The television show Dance India Dance, where Chakraborty was the Grand Master, also entered in the Limca Book of Records and the Guinness World Records.[26] Chakraborty played a crucial mediating role between Pranab Mukherjee of the Indian National Congress and Mamata Banerjee, winning Mukherjee the support of Banerjee's party, the All India Trinamool Congress, in the 2012 Indian presidential election.[27] He joined the Bharatiya Janata Party (BJP) on 7 March 2021, ahead of the 2021 West Bengal Legislative Assembly election.[4]..""".split()))
# Out:
# [('Mithun', 'NNP'), ('Chakraborty', 'NNP'), ('(born', 'NNP'), ('Gouranga', 'NNP'), ('Chakraborty;', 'NNP'), ('16', 'CD'), ('June', 'NNP'), ('1950)', 'CD'), ('is', 'VBZ'), ('an', 'DT'), ('Indian', 'JJ'), ('actor,', 'NN'), ('film', 'NN'), ('producer,', 'NN'), ('screenwriter,', 'NN'), ('entrepreneur', 'NN'), ('and', 'CC'), ('politician', 'NN'), ('who', 'WP'), ('predominantly', 'RB'), ('works', 'VBZ'), ('in', 'IN'), ('Hindi', 'NNP'), ('and', 'CC'), ('Bengali', 'NNP'), ('cinema.', 'NN'), ('In', 'IN'), ('a', 'DT'), ('career', 'NN'), ('spanning', 'NN'), ('over', 'IN'), ('five', 'CD'), ('decades,', 'NN'), ('he', 'PRP'), ('has', 'VBZ'), ('done', 'VBN'), ('350', 'CD'), ('films,', 'NNS'), ('mostly', 'RB'), ('in', 'IN'), ('Hindi', 'NNP'), ('and', 'CC'), ('Bengali', 'NNP'), ('languages,', 'NN'), ('and', 'CC'), ('a', 'DT'), ('few', 'JJ'), ('in', 'IN'), ('Odia,', 'NNP'), ('Telugu,', 'NNP'), ('Kannada,', 'NNP'), ('Punjabi', 'NNP'), ('and', 'CC'), ('Tamil.', 'NNP'), ('He', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('former', 'JJ'), ('Rajya', 'NNP'), ('Sabha', 'NNP'), ('Member', 'NNP'), ('of', 'IN'), ('Parliament.[5][6]', 'NNP'), ('He', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('recipient', 'NN'), ('of', 'IN'), ('three', 'CD'), ('National', 'NNP'), ('Film', 'NNP'), ('Awards', 'NNP'), ('and', 'CC'), ('four', 'CD'), ('Filmfare', 'NNP'), ('Awards.', 'NNP'), ('In', 'IN'), ('January', 'NNP'), ('2024,', 'CD'), ('Chakraborty', 'NNP'), ('was', 'VBD'), ('awarded', 'VBN'), ('Padma', 'NNP'), ('Bhushan,', 'NNP'), ('the', 'DT'), ('third-highest', 'JJ'), ('civilian', 'JJ'), ('honour', 'NN'), ('by', 'IN'), ('the', 'DT'), ('Government', 'NNP'), ('of', 'IN'), ('India.[7][8]', 'NNP'), ('He', 'PRP'), ('was', 'VBD'), ('also', 'RB'), ('awarded', 'VBN'), ("India's", 'NNP'), ('highest', 'JJS'), ('accolade', 'NN'), ('in', 'IN'), ('the', 'DT'), ('field', 'NN'), ('of', 'IN'), ('cinema,', 'NN'), ('the', 'DT'), ('Dadasaheb', 'NNP'), ('Phalke', 'NNP'), ('Award', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('year', 'NN'), ('2022,', 'CD'), ('whose', 'WP$'), ('announcement', 'NN'), ('came', 'VBD'), ('from', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Ministry', 'NNP'), ('of', 'IN'), ('Information', 'NNP'), ('and', 'CC'), ('Broadcasting', 'NNP'), ('in', 'IN'), ('September', 'NNP'), ('2024.[9]', 'CD'), ('Chakraborty', 'NNP'), ('made', 'VBD'), ('his', 'PRP$'), ('acting', 'VBG'), ('debut', 'NN'), ('with', 'IN'), ('the', 'DT'), ('art', 'NN'), ('house', 'NN'), ('drama', 'NN'), ('Mrigayaa', 'NNP'), ('(1976),', 'NNP'), ('directed', 'VBN'), ('by', 'IN'), ('Mrinal', 'NNP'), ('Sen,', 'NNP'), ('for', 'IN'), ('which', 'WDT'), ('he', 'PRP'), ('won', 'VBD'), ('his', 'PRP$'), ('first', 'JJ'), ('National', 'NNP'), ('Film', 'NNP'), ('Award', 'NNP'), ('for', 'IN'), ('Best', 'NNP'), ('Actor.[10]', 'NNP'), ('Chakraborty', 'NNP'), ('gained', 'VBD'), ('greater', 'JJR'), ('fame', 'NN'), ('with', 'IN'), ('the', 'DT'), ('1982', 'CD'), ('film', 'NN'), ('Disco', 'NNP'), ('Dancer,', 'NNP'), ('which', 'WDT'), ('was', 'VBD'), ('a', 'DT'), ('major', 'JJ'), ('box', 'NN'), ('office', 'NN'), ('success', 'NN'), ('in', 'IN'), ('India', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('Soviet', 'JJ'), ('Union.[11]', 'NNP'), ('Besides', 'NNP'), ('Disco', 'NNP'), ('Dancer,', 'NNP'), ('Chakraborty', 'NNP'), ('also', 'RB'), ('gained', 'VBD'), ('recognition', 'NN'), ('for', 'IN'), ('many', 'JJ'), ('other', 'JJ'), ('performances', 'NNS'), ('as', 'IN'), ('both', 'DT'), ('a', 'DT'), ('lead', 'NN'), ('and', 'CC'), ('character', 'NN'), ('artist.[12][13][14][15]', 'VBP'), ("Chakraborty's", 'NNP'), ('performance', 'NN'), ('in', 'IN'), ('Agneepath', 'NNP'), ('won', 'VBD'), ('him', 'PRP'), ('the', 'DT'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('for', 'IN'), ('Best', 'NNP'), ('Supporting', 'NNP'), ('Actor', 'NNP'), ('in', 'IN'), ('1990.[16]', 'CD'), ('Chakraborty', 'NNP'), ('owns', 'VBZ'), ('the', 'DT'), ('Monarch', 'NNP'), ('Group,', 'NNP'), ('which', 'WDT'), ('has', 'VBZ'), ('interests', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('hospitality', 'NN'), ('and ...
