# %%
# # Text lemitization

# ✅ Text Lemmatization – Definition
# Lemmatization is a Natural Language Processing (NLP) technique that reduces a word to its base or dictionary form, called the lemma. Unlike stemming, which may just cut off word endings, lemmatization uses vocabulary and grammar rules to find the correct root word.


import nltk
from  nltk.stem import WordNetLemmatizer

# %%
lemma = WordNetLemmatizer()

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Download WordNet data (only once)
nltk.download('wordnet')
nltk.download('omw-1.4')

# Create lemmatizer object
lemma = WordNetLemmatizer()

# Example words
print(lemma.lemmatize("running", pos="v"))   # Output: run
print(lemma.lemmatize("better", pos="a"))    # Output: good
print(lemma.lemmatize("cars", pos="n"))      # Output: car
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# run
# good
# car

# %%
lemma.lemmatize("going",pos="a")
# Out:
# 'going'

# %%
# List of words for testing
words = [
    "playing",
    "tables",
    "danceable",
    "agrees",
    "bake",
    "riding",
    "laughs",
    "capable",
    "creates",
    "working"
]
words
# Out:
# ['playing',
#  'tables',
#  'danceable',
#  'agrees',
#  'bake',
#  'riding',
#  'laughs',
#  'capable',
#  'creates',
#  'working']

# %%
for word in words:
    print(word + "------>" + lemma.lemmatize(word,pos="a"))
# Out:
# playing------>playing
# tables------>tables
# danceable------>danceable
# agrees------>agrees
# bake------>bake
# riding------>riding
# laughs------>laughs
# capable------>capable
# creates------>creates
# working------>working

# %%
for word in words:
    print(word + "------>" + lemma.lemmatize(word,pos="v"))
# Out:
# playing------>play
# tables------>table
# danceable------>danceable
# agrees------>agree
# bake------>bake
# riding------>rid
# laughs------>laugh
# capable------>capable
# creates------>create
# working------>work

# %%
for word in words:
    print(word + "------>" + lemma.lemmatize(word,pos="n"))
# Out:
# playing------>playing
# tables------>table
# danceable------>danceable
# agrees------>agrees
# bake------>bake
# riding------>riding
# laughs------>laugh
# capable------>capable
# creates------>creates
# working------>working

# %%
lem.lemmatize("going",pos="a")
