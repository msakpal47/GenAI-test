# %%
# Named Entity Recognition  

sentencio = '''The Gateway of India is an arch-monument completed in 1924 on the waterfront of Mumbai (Bombay), India. It was erected to commemorate the landing of George V for his coronation as the Emperor of India in December 1911 at Strand Road near Wellington Fountain. He was the first British monarch to visit India.

The foundation stone was laid in March 1913 for a monument built in the Indo-Saracenic style, inspired by elements of 16th-century Indian architecture. The final design of the monument by architect George Wittet was sanctioned only in 1914, and construction was completed in 1924. The structure is a memorial arch made of basalt, which is 26 metres (85 feet) high, with an architectural resemblance to a triumphial arch

After its construction, the Gateway was used as a symbolic ceremonial entrance to India for important government personnel. The Gateway is also the monument from where the last British troops left in 1948, following Indian independence a year earlier. It is located on the waterfront at an angle, opposite the Taj Mahal Palace and Tower Hotel and overlooks the Arabian Sea. Today, the monument is synonymous with the city of Mumbai, and is amongst its prime tourist attractions. The Gateway is also a gathering spot for locals, street vendors, and photographers soliciting services. It holds significance for the local Jewish community as it has been the spot for Hanukkah celebrations, with the lighting of the menorah, since 2003. There are five jetties located at the Gateway, of which two are used for commercial ferry operations.'''

# %%
sentencio
# Out:
# 'The Gateway of India is an arch-monument completed in 1924 on the waterfront of Mumbai (Bombay), India. It was erected to commemorate the landing of George V for his coronation as the Emperor of India in December 1911 at Strand Road near Wellington Fountain. He was the first British monarch to visit India.\n\nThe foundation stone was laid in March 1913 for a monument built in the Indo-Saracenic style, inspired by elements of 16th-century Indian architecture. The final design of the monument by architect George Wittet was sanctioned only in 1914, and construction was completed in 1924. The structure is a memorial arch made of basalt, which is 26 metres (85 feet) high, with an architectural resemblance to a triumphial arch\n\nAfter its construction, the Gateway was used as a symbolic ceremonial entrance to India for important government personnel. The Gateway is also the monument from where the last British troops left in 1948, following Indian independence a year earlier. It is located on the waterfront at an angle, opposite the Taj Mahal Palace and Tower Hotel and overlooks the Arabian Sea. Today, the monument is synonymous with the city of Mumbai, and is amongst its prime tourist attractions. The Gateway is also a gathering spot for locals, street vendors, and photographers soliciting services. It holds significance for the local Jewish community as it has been the spot for Hanukkah celebrations, with the lighting of the menorah, since 2003. There are five jetties located at the Gateway, of which two are used for commercial ferry operations.'

# %%
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.tree import Tree
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('treebank')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
# Auto-download required resources if not present
for resource in ['maxent_ne_chunker', 'words', 'punkt', 'averaged_perceptron_tagger']:
    try:
        nltk.data.find(resource)
    except LookupError:
        nltk.download(resource)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\FINRISE\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk

try:
    nltk.data.find('chunkers/maxent_ne_chunker')
    print("maxent_ne_chunker is installed.")
except LookupError:
    print("maxent_ne_chunker is NOT installed.")
# Out:
# maxent_ne_chunker is installed.

# %%
try:
    nltk.data.find('corpora/words')
    print("words corpus is installed.")
except LookupError:
    print("words corpus is NOT installed.")
# Out:
# words corpus is installed.

# %%
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\FINRISE/nltk_data', 'c:\\Users\\FINRISE\\AppData\\Local\\Programs\\Python\\Python310\\nltk_data', 'c:\\Users\\FINRISE\\AppData\\Local\\Programs\\Python\\Python310\\share\\nltk_data', 'c:\\Users\\FINRISE\\AppData\\Local\\Programs\\Python\\Python310\\lib\\nltk_data', 'C:\\Users\\FINRISE\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
print(nltk.data.find('chunkers/maxent_ne_chunker_tab'))
print(nltk.data.find('corpora/words'))
# Out:
# C:\Users\FINRISE\AppData\Roaming\nltk_data\chunkers\maxent_ne_chunker_tab
# C:\Users\FINRISE\AppData\Roaming\nltk_data\corpora\words

# %%
word_tokenize(sentencio)
# Out:
# ['The',
#  'Gateway',
#  'of',
#  'India',
#  'is',
#  'an',
#  'arch-monument',
#  'completed',
#  'in',
#  '1924',
#  'on',
#  'the',
#  'waterfront',
#  'of',
#  'Mumbai',
#  '(',
#  'Bombay',
#  ')',
#  ',',
#  'India',
#  '.',
#  'It',
#  'was',
#  'erected',
#  'to',
#  'commemorate',
#  'the',
#  'landing',
#  'of',
#  'George',
#  'V',
#  'for',
#  'his',
#  'coronation',
#  'as',
#  'the',
#  'Emperor',
#  'of',
#  'India',
#  'in',
#  'December',
#  '1911',
#  'at',
#  'Strand',
#  'Road',
#  'near',
#  'Wellington',
#  'Fountain',
#  '.',
#  'He',
#  'was',
#  'the',
#  'first',
#  'British',
#  'monarch',
#  'to',
#  'visit',
#  'India',
#  '.',
#  'The',
#  'foundation',
#  'stone',
#  'was',
#  'laid',
#  'in',
#  'March',
#  '1913',
#  'for',
#  'a',
#  'monument',
#  'built',
#  'in',
#  'the',
#  'Indo-Saracenic',
#  'style',
#  ',',
#  'inspired',
#  'by',
#  'elements',
#  'of',
#  '16th-century',
#  'Indian',
#  'architecture',
#  '.',
#  'The',
#  'final',
#  'design',
#  'of',
#  'the',
#  'monument',
#  'by',
#  'architect',
#  'George',
#  'Wittet',
#  'was',
#  'sanctioned',
#  'only',
#  'in',
#  '1914',
#  ',',
#  'and',
#  'construction',
#  'was',
#  'completed',
#  'in',
#  '1924',
#  '.',
#  'The',
#  'structure',
#  'is',
#  'a',
#  'memorial',
#  'arch',
#  'made',
#  'of',
#  'basalt',
#  ',',
#  'which',
#  'is',
#  '26',
#  'metres',
#  '(',
#  '85',
#  'feet',
#  ')',
#  'high',
#  ',',
#  'with',
#  'an',
#  'architectural',
#  'resemblance',
#  'to',
#  'a',
#  'triumphial',
#  'arch',
#  'After',
#  'its',
#  'construction',
#  ',',
#  'the',
#  'Gateway',
#  'was',
#  'used',
#  'as',
#  'a',
#  'symbolic',
#  'ceremonial',
#  'entrance',
#  'to',
#  'India',
#  'for',
#  'important',
#  'government',
#  'personnel',
#  '.',
#  'The',
#  'Gateway',
#  'is',
#  'also',
#  'the',
#  'monument',
#  'from',
#  'where',
#  'the',
#  'last',
#  'British',
#  'troops',
#  'left',
#  'in',
#  '1948',
#  ',',
#  'following',
#  'Indian',
#  'independence',
#  'a',
#  'year',
#  'earlier',
#  '.',
#  'It',
#  'is',
#  'located',
#  'on',
#  'the',
#  'waterfront',
#  'at',
#  'an',
#  'angle',
#  ',',
#  'opposite',
#  'the',
#  'Taj',
#  'Mahal',
#  'Palace',
#  'and',
#  'Tower',
#  'Hotel',
#  'and',
#  'overlooks',
#  'the',
#  'Arabian',
#  'Sea',
#  '.',
#  'Today',
#  ',',
#  'the',
#  'monument',
#  'is',
#  'synonymous',
#  'with',
#  'the',
#  'city',
#  'of',
#  'Mumbai',
#  ',',
#  'and',
#  'is',
#  'amongst',
#  'its',
#  'prime',
#  'tourist',
#  'attractions',
#  '.',
#  'The',
#  'Gateway',
#  'is',
#  'also',
#  'a',
#  'gathering',
#  'spot',
#  'for',
#  'locals',
#  ',',
#  'street',
#  'vendors',
#  ',',
#  'and',
#  'photographers',
#  'soliciting',
#  'services',
#  '.',
#  'It',
#  'holds',
#  'significance',
#  'for',
#  'the',
#  'local',
#  'Jewish',
#  'community',
#  'as',
#  'it',
#  'has',
#  'been',
#  'the',
#  'spot',
#  'for',
#  'Hanukkah',
#  'celebrations',
#  ',',
#  'with',
#  'the',
#  'lighting',
#  'of',
#  'the',
#  'menorah',
#  ',',
#  'since',
#  '2003',
#  '.',
#  'There',
#  'are',
#  'five',
#  'jetties',
#  'located',
#  'at',
#  'the',
#  'Gateway',
#  ',',
#  'of',
#  'which',
#  'two',
#  'are',
#  'used',
#  'for',
#  'commercial',
#  'ferry',
#  'operations',
#  '.']

# %%
tokens = word_tokenize(sentencio)

# %%
tokens
# Out:
# ['The',
#  'Gateway',
#  'of',
#  'India',
#  'is',
#  'an',
#  'arch-monument',
#  'completed',
#  'in',
#  '1924',
#  'on',
#  'the',
#  'waterfront',
#  'of',
#  'Mumbai',
#  '(',
#  'Bombay',
#  ')',
#  ',',
#  'India',
#  '.',
#  'It',
#  'was',
#  'erected',
#  'to',
#  'commemorate',
#  'the',
#  'landing',
#  'of',
#  'George',
#  'V',
#  'for',
#  'his',
#  'coronation',
#  'as',
#  'the',
#  'Emperor',
#  'of',
#  'India',
#  'in',
#  'December',
#  '1911',
#  'at',
#  'Strand',
#  'Road',
#  'near',
#  'Wellington',
#  'Fountain',
#  '.',
#  'He',
#  'was',
#  'the',
#  'first',
#  'British',
#  'monarch',
#  'to',
#  'visit',
#  'India',
#  '.',
#  'The',
#  'foundation',
#  'stone',
#  'was',
#  'laid',
#  'in',
#  'March',
#  '1913',
#  'for',
#  'a',
#  'monument',
#  'built',
#  'in',
#  'the',
#  'Indo-Saracenic',
#  'style',
#  ',',
#  'inspired',
#  'by',
#  'elements',
#  'of',
#  '16th-century',
#  'Indian',
#  'architecture',
#  '.',
#  'The',
#  'final',
#  'design',
#  'of',
#  'the',
#  'monument',
#  'by',
#  'architect',
#  'George',
#  'Wittet',
#  'was',
#  'sanctioned',
#  'only',
#  'in',
#  '1914',
#  ',',
#  'and',
#  'construction',
#  'was',
#  'completed',
#  'in',
#  '1924',
#  '.',
#  'The',
#  'structure',
#  'is',
#  'a',
#  'memorial',
#  'arch',
#  'made',
#  'of',
#  'basalt',
#  ',',
#  'which',
#  'is',
#  '26',
#  'metres',
#  '(',
#  '85',
#  'feet',
#  ')',
#  'high',
#  ',',
#  'with',
#  'an',
#  'architectural',
#  'resemblance',
#  'to',
#  'a',
#  'triumphial',
#  'arch',
#  'After',
#  'its',
#  'construction',
#  ',',
#  'the',
#  'Gateway',
#  'was',
#  'used',
#  'as',
#  'a',
#  'symbolic',
#  'ceremonial',
#  'entrance',
#  'to',
#  'India',
#  'for',
#  'important',
#  'government',
#  'personnel',
#  '.',
#  'The',
#  'Gateway',
#  'is',
#  'also',
#  'the',
#  'monument',
#  'from',
#  'where',
#  'the',
#  'last',
#  'British',
#  'troops',
#  'left',
#  'in',
#  '1948',
#  ',',
#  'following',
#  'Indian',
#  'independence',
#  'a',
#  'year',
#  'earlier',
#  '.',
#  'It',
#  'is',
#  'located',
#  'on',
#  'the',
#  'waterfront',
#  'at',
#  'an',
#  'angle',
#  ',',
#  'opposite',
#  'the',
#  'Taj',
#  'Mahal',
#  'Palace',
#  'and',
#  'Tower',
#  'Hotel',
#  'and',
#  'overlooks',
#  'the',
#  'Arabian',
#  'Sea',
#  '.',
#  'Today',
#  ',',
#  'the',
#  'monument',
#  'is',
#  'synonymous',
#  'with',
#  'the',
#  'city',
#  'of',
#  'Mumbai',
#  ',',
#  'and',
#  'is',
#  'amongst',
#  'its',
#  'prime',
#  'tourist',
#  'attractions',
#  '.',
#  'The',
#  'Gateway',
#  'is',
#  'also',
#  'a',
#  'gathering',
#  'spot',
#  'for',
#  'locals',
#  ',',
#  'street',
#  'vendors',
#  ',',
#  'and',
#  'photographers',
#  'soliciting',
#  'services',
#  '.',
#  'It',
#  'holds',
#  'significance',
#  'for',
#  'the',
#  'local',
#  'Jewish',
#  'community',
#  'as',
#  'it',
#  'has',
#  'been',
#  'the',
#  'spot',
#  'for',
#  'Hanukkah',
#  'celebrations',
#  ',',
#  'with',
#  'the',
#  'lighting',
#  'of',
#  'the',
#  'menorah',
#  ',',
#  'since',
#  '2003',
#  '.',
#  'There',
#  'are',
#  'five',
#  'jetties',
#  'located',
#  'at',
#  'the',
#  'Gateway',
#  ',',
#  'of',
#  'which',
#  'two',
#  'are',
#  'used',
#  'for',
#  'commercial',
#  'ferry',
#  'operations',
#  '.']

# %%
pos_tag(tokens)
# Out:
# [('The', 'DT'),
#  ('Gateway', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('arch-monument', 'JJ'),
#  ('completed', 'VBN'),
#  ('in', 'IN'),
#  ('1924', 'CD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('waterfront', 'NN'),
#  ('of', 'IN'),
#  ('Mumbai', 'NNP'),
#  ('(', '('),
#  ('Bombay', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('erected', 'VBN'),
#  ('to', 'TO'),
#  ('commemorate', 'VB'),
#  ('the', 'DT'),
#  ('landing', 'NN'),
#  ('of', 'IN'),
#  ('George', 'NNP'),
#  ('V', 'NNP'),
#  ('for', 'IN'),
#  ('his', 'PRP$'),
#  ('coronation', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Emperor', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('in', 'IN'),
#  ('December', 'NNP'),
#  ('1911', 'CD'),
#  ('at', 'IN'),
#  ('Strand', 'NNP'),
#  ('Road', 'NNP'),
#  ('near', 'IN'),
#  ('Wellington', 'NNP'),
#  ('Fountain', 'NNP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('British', 'JJ'),
#  ('monarch', 'NN'),
#  ('to', 'TO'),
#  ('visit', 'VB'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('foundation', 'NN'),
#  ('stone', 'NN'),
#  ('was', 'VBD'),
#  ('laid', 'VBN'),
#  ('in', 'IN'),
#  ('March', 'NNP'),
#  ('1913', 'CD'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('monument', 'NN'),
#  ('built', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Indo-Saracenic', 'JJ'),
#  ('style', 'NN'),
#  (',', ','),
#  ('inspired', 'VBN'),
#  ('by', 'IN'),
#  ('elements', 'NNS'),
#  ('of', 'IN'),
#  ('16th-century', 'JJ'),
#  ('Indian', 'JJ'),
#  ('architecture', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('final', 'JJ'),
#  ('design', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('monument', 'NN'),
#  ('by', 'IN'),
#  ('architect', 'NN'),
#  ('George', 'NNP'),
#  ('Wittet', 'NNP'),
#  ('was', 'VBD'),
#  ('sanctioned', 'VBN'),
#  ('only', 'RB'),
#  ('in', 'IN'),
#  ('1914', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('construction', 'NN'),
#  ('was', 'VBD'),
#  ('completed', 'VBN'),
#  ('in', 'IN'),
#  ('1924', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('structure', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('memorial', 'JJ'),
#  ('arch', 'NN'),
#  ('made', 'VBN'),
#  ('of', 'IN'),
#  ('basalt', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('26', 'CD'),
#  ('metres', 'NNS'),
#  ('(', '('),
#  ('85', 'CD'),
#  ('feet', 'NNS'),
#  (')', ')'),
#  ('high', 'VBP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('architectural', 'JJ'),
#  ('resemblance', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('triumphial', 'JJ'),
#  ('arch', 'NN'),
#  ('After', 'IN'),
#  ('its', 'PRP$'),
#  ('construction', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Gateway', 'NNP'),
#  ('was', 'VBD'),
#  ('used', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('symbolic', 'JJ'),
#  ('ceremonial', 'JJ'),
#  ('entrance', 'NN'),
#  ('to', 'TO'),
#  ('India', 'NNP'),
#  ('for', 'IN'),
#  ('important', 'JJ'),
#  ('government', 'NN'),
#  ('personnel', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Gateway', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('the', 'DT'),
#  ('monument', 'NN'),
#  ('from', 'IN'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('British', 'JJ'),
#  ('troops', 'NNS'),
#  ('left', 'VBN'),
#  ('in', 'IN'),
#  ('1948', 'CD'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('Indian', 'JJ'),
#  ('independence', 'NN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('earlier', 'RBR'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('located', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('waterfront', 'NN'),
#  ('at', 'IN'),
#  ('an', 'DT'),
#  ('angle', 'NN'),
#  (',', ','),
#  ('opposite', 'VBP'),
#  ('the', 'DT'),
#  ('Taj', 'NNP'),
#  ('Mahal', 'NNP'),
#  ('Palace', 'NNP'),
#  ('and', 'CC'),
#  ('Tower', 'NNP'),
#  ('Hotel', 'NNP'),
#  ('and', 'CC'),
#  ('overlooks', 'VBZ'),
#  ('the', 'DT'),
#  ('Arabian', 'JJ'),
#  ('Sea', 'NNP'),
#  ('.', '.'),
#  ('Today', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('monument', 'NN'),
#  ('is', 'VBZ'),
#  ('synonymous', 'JJ'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Mumbai', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('is', 'VBZ'),
#  ('amongst', 'VBG'),
#  ('its', 'PRP$'),
#  ('prime', 'JJ'),
#  ('tourist', 'NN'),
#  ('attractions', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Gateway', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('a', 'DT'),
#  ('gathering', 'NN'),
#  ('spot', 'NN'),
#  ('for', 'IN'),
#  ('locals', 'NNS'),
#  (',', ','),
#  ('street', 'NN'),
#  ('vendors', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('photographers', 'NNS'),
#  ('soliciting', 'VBG'),
#  ('services', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('holds', 'VBZ'),
#  ('significance', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('local', 'JJ'),
#  ('Jewish', 'NNP'),
#  ('community', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('the', 'DT'),
#  ('spot', 'NN'),
#  ('for', 'IN'),
#  ('Hanukkah', 'NNP'),
#  ('celebrations', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('lighting', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('menorah', 'NN'),
#  (',', ','),
#  ('since', 'IN'),
#  ('2003', 'CD'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('five', 'CD'),
#  ('jetties', 'NNS'),
#  ('located', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Gateway', 'NNP'),
#  (',', ','),
#  ('of', 'IN'),
#  ('which', 'WDT'),
#  ('two', 'CD'),
#  ('are', 'VBP'),
#  ('used', 'VBN'),
#  ('for', 'IN'),
#  ('commercial', 'JJ'),
#  ('ferry', 'NN'),
#  ('operations', 'NNS'),
#  ('.', '.')]

# %%
tagged = pos_tag(tokens)

# %%
ne_chunk(tagged)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Gateway', 'NNP')]), ('of', 'IN'), Tree('GPE', [('India', 'NNP')]), ('is', 'VBZ'), ('an', 'DT'), ('arch-monument', 'JJ'), ('completed', 'VBN'), ('in', 'IN'), ('1924', 'CD'), ('on', 'IN'), ('the', 'DT'), ('waterfront', 'NN'), ('of', 'IN'), Tree('GPE', [('Mumbai', 'NNP')]), ('(', '('), Tree('GPE', [('Bombay', 'NNP')]), (')', ')'), (',', ','), Tree('GPE', [('India', 'NNP')]), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('erected', 'VBN'), ('to', 'TO'), ('commemorate', 'VB'), ('the', 'DT'), ('landing', 'NN'), ('of', 'IN'), Tree('PERSON', [('George', 'NNP'), ('V', 'NNP')]), ('for', 'IN'), ('his', 'PRP$'), ('coronation', 'NN'), ('as', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Emperor', 'NNP')]), ('of', 'IN'), Tree('GPE', [('India', 'NNP')]), ('in', 'IN'), ('December', 'NNP'), ('1911', 'CD'), ('at', 'IN'), Tree('FACILITY', [('Strand', 'NNP'), ('Road', 'NNP')]), ('near', 'IN'), Tree('PERSON', [('Wellington', 'NNP'), ('Fountain', 'NNP')]), ('.', '.'), ('He', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('first', 'JJ'), Tree('GPE', [('British', 'JJ')]), ('monarch', 'NN'), ('to', 'TO'), ('visit', 'VB'), Tree('GPE', [('India', 'NNP')]), ('.', '.'), ('The', 'DT'), ('foundation', 'NN'), ('stone', 'NN'), ('was', 'VBD'), ('laid', 'VBN'), ('in', 'IN'), ('March', 'NNP'), ('1913', 'CD'), ('for', 'IN'), ('a', 'DT'), ('monument', 'NN'), ('built', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('Indo-Saracenic', 'JJ'), ('style', 'NN'), (',', ','), ('inspired', 'VBN'), ('by', 'IN'), ('elements', 'NNS'), ('of', 'IN'), ('16th-century', 'JJ'), Tree('GPE', [('Indian', 'JJ')]), ('architecture', 'NN'), ('.', '.'), ('The', 'DT'), ('final', 'JJ'), ('design', 'NN'), ('of', 'IN'), ('the', 'DT'), ('monument', 'NN'), ('by', 'IN'), ('architect', 'NN'), Tree('PERSON', [('George', 'NNP'), ('Wittet', 'NNP')]), ('was', 'VBD'), ('sanctioned', 'VBN'), ('only', 'RB'), ('in', 'IN'), ('1914', 'CD'), (',', ','), ('and', 'CC'), ('construction', 'NN'), ('was', 'VBD'), ('completed', 'VBN'), ('in', 'IN'), ('1924', 'CD'), ('.', '.'), ('The', 'DT'), ('structure', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('memorial', 'JJ'), ('arch', 'NN'), ('made', 'VBN'), ('of', 'IN'), ('basalt', 'NN'), (',', ','), ('which', 'WDT'), ('is', 'VBZ'), ('26', 'CD'), ('metres', 'NNS'), ('(', '('), ('85', 'CD'), ('feet', 'NNS'), (')', ')'), ('high', 'VBP'), (',', ','), ('with', 'IN'), ('an', 'DT'), ('architectural', 'JJ'), ('resemblance', 'NN'), ('to', 'TO'), ('a', 'DT'), ('triumphial', 'JJ'), ('arch', 'NN'), ('After', 'IN'), ('its', 'PRP$'), ('construction', 'NN'), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('Gateway', 'NNP')]), ('was', 'VBD'), ('used', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('symbolic', 'JJ'), ('ceremonial', 'JJ'), ('entrance', 'NN'), ('to', 'TO'), Tree('GPE', [('India', 'NNP')]), ('for', 'IN'), ('important', 'JJ'), ('government', 'NN'), ('personnel', 'NNS'), ('.', '.'), ('The', 'DT'), Tree('ORGANIZATION', [('Gateway', 'NNP')]), ('is', 'VBZ'), ('also', 'RB'), ('the', 'DT'), ('monument', 'NN'), ('from', 'IN'), ('where', 'WRB'), ('the', 'DT'), ('last', 'JJ'), Tree('GPE', [('British', 'JJ')]), ('troops', 'NNS'), ('left', 'VBN'), ('in', 'IN'), ('1948', 'CD'), (',', ','), ('following', 'VBG'), Tree('GPE', [('Indian', 'JJ')]), ('independence', 'NN'), ('a', 'DT'), ('year', 'NN'), ('earlier', 'RBR'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('located', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('waterfront', 'NN'), ('at', 'IN'), ('an', 'DT'), ('angle', 'NN'), (',', ','), ('opposite', 'VBP'), ('the', 'DT'), Tree('ORGANIZATION', [('Taj', 'NNP'), ('Mahal', 'NNP'), ('Palace', 'NNP')]), ('and', 'CC'), Tree('PERSON', [('Tower', 'NNP'), ('Hotel', 'NNP')]), ('and', 'CC'), ('overlooks', 'VBZ'), ('the', 'DT'), Tree('PERSON', [('Arabian', 'JJ'), ('Sea', 'NNP')]), ('.', '.'), ('Today', 'NN'), (',', ','), ('the', 'DT'), ('monument', 'NN'), ('is', 'VBZ'), ('synonymous', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('city', 'NN'), ('of', 'IN'), Tree('GPE', [('Mumbai', 'NNP')]), (',',  ...

# %%
ner_tree = ne_chunk(tagged)

# %%
print(ner_tree)
# Out:
# (S
#   The/DT
#   (ORGANIZATION Gateway/NNP)
#   of/IN
#   (GPE India/NNP)
#   is/VBZ
#   an/DT
#   arch-monument/JJ
#   completed/VBN
#   in/IN
#   1924/CD
#   on/IN
#   the/DT
#   waterfront/NN
#   of/IN
#   (GPE Mumbai/NNP)
#   (/(
#   (GPE Bombay/NNP)
#   )/)
#   ,/,
#   (GPE India/NNP)
#   ./.
#   It/PRP
#   was/VBD
#   erected/VBN
#   to/TO
#   commemorate/VB
#   the/DT
#   landing/NN
#   of/IN
#   (PERSON George/NNP V/NNP)
#   for/IN
#   his/PRP$
#   coronation/NN
#   as/IN
#   the/DT
#   (ORGANIZATION Emperor/NNP)
#   of/IN
#   (GPE India/NNP)
#   in/IN
#   December/NNP
#   1911/CD
#   at/IN
#   (FACILITY Strand/NNP Road/NNP)
#   near/IN
#   (PERSON Wellington/NNP Fountain/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   the/DT
#   first/JJ
#   (GPE British/JJ)
#   monarch/NN
#   to/TO
#   visit/VB
#   (GPE India/NNP)
#   ./.
#   The/DT
#   foundation/NN
#   stone/NN
#   was/VBD
#   laid/VBN
#   in/IN
#   March/NNP
#   1913/CD
#   for/IN
#   a/DT
#   monument/NN
#   built/VBN
#   in/IN
#   the/DT
#   Indo-Saracenic/JJ
#   style/NN
#   ,/,
#   inspired/VBN
#   by/IN
#   elements/NNS
#   of/IN
#   16th-century/JJ
#   (GPE Indian/JJ)
#   architecture/NN
#   ./.
#   The/DT
#   final/JJ
#   design/NN
#   of/IN
#   the/DT
#   monument/NN
#   by/IN
#   architect/NN
#   (PERSON George/NNP Wittet/NNP)
#   was/VBD
#   sanctioned/VBN
#   only/RB
#   in/IN
#   1914/CD
#   ,/,
#   and/CC
#   construction/NN
#   was/VBD
#   completed/VBN
#   in/IN
#   1924/CD
#   ./.
#   The/DT
#   structure/NN
#   is/VBZ
#   a/DT
#   memorial/JJ
#   arch/NN
#   made/VBN
#   of/IN
#   basalt/NN
#   ,/,
#   which/WDT
#   is/VBZ
#   26/CD
#   metres/NNS
#   (/(
#   85/CD
#   feet/NNS
#   )/)
#   high/VBP
#   ,/,
#   with/IN
#   an/DT
#   architectural/JJ
#   resemblance/NN
#   to/TO
#   a/DT
#   triumphial/JJ
#   arch/NN
#   After/IN
#   its/PRP$
#   construction/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Gateway/NNP)
#   was/VBD
#   used/VBN
#   as/IN
#   a/DT
#   symbolic/JJ
#   ceremonial/JJ
#   entrance/NN
#   to/TO
#   (GPE India/NNP)
#   for/IN
#   important/JJ
#   government/NN
#   personnel/NNS
#   ./.
#   The/DT
#   (ORGANIZATION Gateway/NNP)
#   is/VBZ
#   also/RB
#   the/DT
#   monument/NN
#   from/IN
#   where/WRB
#   the/DT
#   last/JJ
#   (GPE British/JJ)
#   troops/NNS
#   left/VBN
#   in/IN
#   1948/CD
#   ,/,
#   following/VBG
#   (GPE Indian/JJ)
#   independence/NN
#   a/DT
#   year/NN
#   earlier/RBR
#   ./.
#   It/PRP
#   is/VBZ
#   located/VBN
#   on/IN
#   the/DT
#   waterfront/NN
#   at/IN
#   an/DT
#   angle/NN
#   ,/,
#   opposite/VBP
#   the/DT
#   (ORGANIZATION Taj/NNP Mahal/NNP Palace/NNP)
#   and/CC
#   (PERSON Tower/NNP Hotel/NNP)
#   and/CC
#   overlooks/VBZ
#   the/DT
#   (PERSON Arabian/JJ Sea/NNP)
#   ./.
#   Today/NN
#   ,/,
#   the/DT
#   monument/NN
#   is/VBZ
#   synonymous/JJ
#   with/IN
#   the/DT
#   city/NN
#   of/IN
#   (GPE Mumbai/NNP)
#   ,/,
#   and/CC
#   is/VBZ
#   amongst/VBG
#   its/PRP$
#   prime/JJ
#   tourist/NN
#   attractions/NNS
#   ./.
#   The/DT
#   (ORGANIZATION Gateway/NNP)
#   is/VBZ
#   also/RB
#   a/DT
#   gathering/NN
#   spot/NN
#   for/IN
#   locals/NNS
#   ,/,
#   street/NN
#   vendors/NNS
#   ,/,
#   and/CC
#   photographers/NNS
#   soliciting/VBG
#   services/NNS
#   ./.
#   It/PRP
#   holds/VBZ
#   significance/NN
#   for/IN
#   the/DT
#   local/JJ
#   Jewish/NNP
#   community/NN
#   as/IN
#   it/PRP
#   has/VBZ
#   been/VBN
#   the/DT
#   spot/NN
#   for/IN
#   (ORGANIZATION Hanukkah/NNP)
#   celebrations/NNS
#   ,/,
#   with/IN
#   the/DT
#   lighting/NN
#   of/IN
#   the/DT
#   menorah/NN
#   ,/,
#   since/IN
#   2003/CD
#   ./.
#   There/EX
#   are/VBP
#   five/CD
#   jetties/NNS
#   located/VBN
#   at/IN
#   the/DT
#   (GPE Gateway/NNP)
#   ,/,
#   of/IN
#   which/WDT
#   two/CD
#   are/VBP
#   used/VBN
#   for/IN
#   commercial/JJ
#   ferry/NN
#   operations/NNS
#   ./.)

# %%
ner_tree.draw()
