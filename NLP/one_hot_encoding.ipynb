# %%
# # one hot encoding
# # One-Hot Encoding is a method used to convert categorical variables into numerical format so they can be used in machine learning models.
# ✅ Why do we need it?
# Machine learning algorithms cannot directly process text labels like "red", "blue", or "green". They need numerical values.
# # If we just assign numbers (e.g., red=1, blue=2, green=3), the model might think green > blue > red, which is wrong because these categories have no inherent order.

# %%
# D1 the food is good
# D2 the food is bad
# D3 pizza is amazing

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
# Documents with IDs
docs = {
    "D1": "the food is good",
    "D2": "the food is bad",
    "D3": "pizza is amazing"
}

# %%
docs
# Out:
# {'D1': 'the food is good', 'D2': 'the food is bad', 'D3': 'pizza is amazing'}

# %%
# Extract sentences and labels
docs.keys()
# Out:
# dict_keys(['D1', 'D2', 'D3'])

# %%
list(docs.keys())
# Out:
# ['D1', 'D2', 'D3']

# %%
labels = list(docs.keys())

# %%
labels
# Out:
# ['D1', 'D2', 'D3']

# %%
docs.values()
# Out:
# dict_values(['the food is good', 'the food is bad', 'pizza is amazing'])

# %%
list(docs.values())
# Out:
# ['the food is good', 'the food is bad', 'pizza is amazing']

# %%
senetceon = list(docs.values())

# %%
senetceon
# Out:
# ['the food is good', 'the food is bad', 'pizza is amazing']

# %%
# Create the one-hot encoded matrix
CountVectorizer(binary=True)
# Out:
# CountVectorizer(binary=True)

# %%
vectorizer = CountVectorizer(binary=True)

# %%
vectorizer.fit_transform(senetceon)
# Out:
# <3x7 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11 stored elements in Compressed Sparse Row format>

# %%
one_hot_encoding = vectorizer.fit_transform(senetceon)

# %%
# Create a DataFrame with feature names as columns and labels as index
pd.DataFrame(one_hot_encoding.toarray(),columns=vectorizer.get_feature_names_out(),index=labels)
# Out:
#     amazing  bad  food  good  is  pizza  the
# D1        0    0     1     1   1      0    1
# D2        0    1     1     0   1      0    1
# D3        1    0     0     0   1      1    0

# %%
df = pd.DataFrame(one_hot_encoding.toarray(),columns=vectorizer.get_feature_names_out(),index=labels)

# %%
df
# Out:
#     amazing  bad  food  good  is  pizza  the
# D1        0    0     1     1   1      0    1
# D2        0    1     1     0   1      0    1
# D3        1    0     0     0   1      1    0

# %%
# Tokenize and Create Vocabulary

all_words = set()
for text in docs.values():
    all_words.update(text.split())

# %%
# Sort for consistent order
sorted(all_words)
# Out:
# ['amazing', 'bad', 'food', 'good', 'is', 'pizza', 'the']

# %%
vocab = sorted(all_words)

# %%
{word:i for i, word in enumerate(vocab)}
# Out:
# {'amazing': 0, 'bad': 1, 'food': 2, 'good': 3, 'is': 4, 'pizza': 5, 'the': 6}

# %%
word_to_index = {word:i for i, word in enumerate(vocab)}

# %%
print(word_to_index)
# Out:
# {'amazing': 0, 'bad': 1, 'food': 2, 'good': 3, 'is': 4, 'pizza': 5, 'the': 6}

# %%
print("vocabulary:",vocab)
# Out:
# vocabulary: ['amazing', 'bad', 'food', 'good', 'is', 'pizza', 'the']

# %%
#Document-level One-Hot Encoding
print("n\Document-level One-Hot Encoding:")
doc_encoding = {}
for doc_id, text in docs.items():
    vector = [0] * len(vocab)
    for word in text.split():
        vector[word_to_index[word]] = 1
    doc_encoding[doc_id] = vector
    print(f"{doc_id}:{vector}")
# Out:
# n\Document-level One-Hot Encoding:
# D1:[0, 0, 1, 1, 1, 0, 1]
# D2:[0, 1, 1, 0, 1, 0, 1]
# D3:[1, 0, 0, 0, 1, 1, 0]

# %%
# Word-level One-Hot Encoding

print("n\Document-level One-Hot Encoding:")
for word in vocab:
    vector = [0] * len(vocab)
    vector[word_to_index[word]] = 1
    print(f"{word}:{vector}")
# Out:
# n\Document-level One-Hot Encoding:
# amazing:[1, 0, 0, 0, 0, 0, 0]
# bad:[0, 1, 0, 0, 0, 0, 0]
# food:[0, 0, 1, 0, 0, 0, 0]
# good:[0, 0, 0, 1, 0, 0, 0]
# is:[0, 0, 0, 0, 1, 0, 0]
# pizza:[0, 0, 0, 0, 0, 1, 0]
# the:[0, 0, 0, 0, 0, 0, 1]
