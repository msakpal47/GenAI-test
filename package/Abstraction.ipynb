# %%
# abstraction

from abc import ABC ,abstractmethod

# %%
# Abstract Class

## Abstract BAse class

class Vehicle(ABC):
    def drive (self):
        print("Vehicle is now ready to use")
        
    @abstractmethod
    def start_engine(Vehicle):
        pass
        
class Car (Vehicle):
    def start_engine(self):
        print("Car has been start")
        
def operate_vehicle(Vehicle):
    Vehicle.start_engine()
    
car =Car()

operate_vehicle(car)
# Out:
# Car has been start

# %%
# Abstract Class

## Abstract BAse class

class Vehicle(ABC):
    def drive(self):
        print("The engine is ready to use and work")
    
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car engine has been started")

def operate_vehicle(Vehicle):
    Vehicle.drive()
    Vehicle.start_engine()


car =Car()
operate_vehicle(car)
# Out:
# The engine is ready to use and work
# Car engine has been started

# %%
## Test Code  Full Python Code Example

from abc import ABC, abstractmethod

# base Class 

class Vehicle(ABC):
    def __init__(self,Model,Engine,Door,Capacity):
        self.__Model = Model
        self.__Engine = Engine
        self.__Door = Door
        self.__Capacity = Capacity
        
        
    # getter and setter method
    
    def get_Model(self):
        return self.__Model
    
    def set_Model(self,Model):
        self.__Model = Model
    
    def get_Engine_(self):
        return self.__Engine
    
    def set_Engine(self,Engine):
        self.__Engine = Engine
    
    def get_Door(self):
        return self.__Door
    
    def set_Door(self,Door):
        self.__Door = Door
        
    def get_Capacity(self):
        return self.__Capacity
    
    def set_capacity(self,Capacity):
        self.__Capacity = Capacity
        
    def drive(self):
        print(f"The {self.__Model} is now driving.")
        print(f"It has a sitting capacity of {self.__Capacity} passengers")
        print(f"The vehicle comes with {self.__Door} Doors.")
        print(f"It runs on a {self.__Engine} engine.")
    
    
        
    @abstractmethod
    def start_engine(self):
        pass
    
# Car class → Inheritance
    

class Car(Vehicle):
    def start_engine(self):
        print(f"The car model {self.get_Model()} has started its engine smoothly with a key ignition.")
        print(f"Passenger Carrying Capacity: {self.get_Capacity()}")

    
class Bus(Vehicle):
    def start_engine(self):
        print(f"{self.get_Model()} roars to life as the engine starts with a turn of the key.")
        print(f"it can Carry {self.get_Capacity()} Passenger")


# Truck class with loading capacity

class Truck(Vehicle):
    def __init__(self, Model, Engine, Door, Capacity,Load_capacity_kg):
        super().__init__(Model, Engine, Door, Capacity)
        self.__Load_capacity_kg = Load_capacity_kg
        
    def get_Load_capacity_kg(self):
        return self.__Load_capacity_kg
    
    def start_engine(self):
        print(f"The truck model {self.get_Model()} started with remote ignition.")
        print(f"Loading capacity: {self.__Load_capacity_kg} kg/Ton")
        
       


# Function demonstrating Polymorphism

def operate_vehicle(Vehicle):
    Vehicle.start_engine()
    Vehicle.drive()
    Vehicle.get_Capacity()
    print(f"Capacity: {Vehicle.get_Capacity()} passengers\n")
    

# Example usage  
car = Car("Padmini","Petrol",4,5)
bus = Bus("Ashok_Leyland","Disel",2,30)
truck = Truck ("TATA","Petrol",2,0,10000)

# Operate all vehicles (polymorphism)
#print(dir(car))
operate_vehicle(car)
operate_vehicle(bus)
operate_vehicle(truck)
# Out:
# The car model Padmini has started its engine smoothly with a key ignition.
# Passenger Carrying Capacity: 5
# The Padmini is now driving.
# It has a sitting capacity of 5 passengers
# The vehicle comes with 4 Doors.
# It runs on a Petrol engine.
# Capacity: 5 passengers
#
# Ashok_Leyland roars to life as the engine starts with a turn of the key.
# it can Carry 30 Passenger
# The Ashok_Leyland is now driving.
# It has a sitting capacity of 30 passengers
# The vehicle comes with 2 Doors.
# It runs on a Disel engine.
# Capacity: 30 passengers
#
# The truck model TATA started with remote ignition.
# Loading capacity: 10000 kg/Ton
# The TATA is now driving.
# It has a sitting capacity of 0 passengers
# The vehicle comes with 2 Doors.
# It runs on a Petrol engine.
# Capacity: 0 passengers

# %%
car.start_engine()
bus.start_engine()
truck.start_engine()
# Out:
# The car model Padmini has started its engine smoothly with a key ignition.
# Passenger Carrying Capacity: 5
# Ashok_Leyland roars to life as the engine starts with a turn of the key.
# it can Carry 30 Passenger
# The truck model TATA started with remote ignition.
# Loading capacity: 10000 kg/Ton

# %%
# set Method use

truck.set_Engine("Disel")
operate_vehicle(truck)
# Out:
# The truck model TATA started with remote ignition.
# Loading capacity: 10000 kg/Ton
# The TATA is now driving.
# It has a sitting capacity of 0 passengers
# The vehicle comes with 2 Doors.
# It runs on a Disel engine.
# Capacity: 0 passengers

# %%
from abc import ABC, abstractmethod

#Base Class
class Vehicle(ABC):
    def __init__(self,Model,Engine,Door,Capacity):
        self.__Model = Model
        self.__Engine = Engine
        self.__Door = Door
        self.__Capacity = Capacity
    
    # Getter and Setter Method
    def get_Model(self):
        return self.__Model
    def set_Model(self,Model):
        self.__Model = Model
        
    def get_Engine(self):
        return self.__Engine
    def set_Engine(self,Engine):
        self.__Engine = Engine
        
    def get_Door(self):
        return self.__Door
    def set_Door(self, Door):
        self.__Door = Door
        
    def get_Capacity(self):
        return self.__Capacity 
    def set_Capacity(self,Capacity):
        self.__Capacity = Capacity
     
    def drive(self):
        print(f"The {self.__Model} is now driving.")
        print(f"It has a sitting capacity of {self.__Capacity} passengers")
        print(f"The vehicle comes with {self.__Door} Doors.")
        print(f"It runs on a {self.__Engine} engine.")
        
    @abstractmethod
    def start_engine(self):
        pass
    
    
# Car class → Inheritance

class Car(Vehicle):
    def start_engine(self):
        print(f"{self.get_Model()} roars to life as the engine starts with a turn of the key.")
        print(f"it can Carry {self.get_Capacity()} Passenger")
        
        
# Bus class → Inheritance

class Bus(Vehicle):
    def start_engine(self):
        print(f"{self.get_Model()} roars to life as the engine starts with a turn of the key.")
        print(f"it can Carry {self.get_Capacity()} Passenger")
        
    
# Truck class with loading capacity

class Truck (Vehicle):
    def __init__(self, Model, Engine, Door, Capacity,Load_Capacity_Kg):
        super().__init__(Model, Engine, Door, Capacity)
        self.__Load_Capacity_Kg = Load_Capacity_Kg
        
    
    def get_Load_Capacity_Kg(self):
        return self.__Load_Capacity_Kg
    
    def start_engine(self):
        print(f"The truck model {self.get_Model()} started with remote ignition.")
        print(f"Loading capacity: {self.__Load_Capacity_Kg} kg/Ton")
        
# Function demonstrating Polymorphism

def operate_vehicle(Vehicle):
    Vehicle.start_engine()
    Vehicle.drive()
    Vehicle.get_Capacity()
    print(f"Capacity: {Vehicle.get_Capacity()} passengers\n")
    

# Example usage  
car = Car("Padmini","Petrol",4,5)
bus = Bus("Ashok_Leyland","Disel",2,30)
truck = Truck ("TATA","Petrol",2,0,10000)

operate_vehicle(car)
operate_vehicle(bus)
operate_vehicle(truck)
# Out:
# Padmini roars to life as the engine starts with a turn of the key.
# it can Carry 5 Passenger
# The Padmini is now driving.
# It has a sitting capacity of 5 passengers
# The vehicle comes with 4 Doors.
# It runs on a Petrol engine.
# Capacity: 5 passengers
#
# Ashok_Leyland roars to life as the engine starts with a turn of the key.
# it can Carry 30 Passenger
# The Ashok_Leyland is now driving.
# It has a sitting capacity of 30 passengers
# The vehicle comes with 2 Doors.
# It runs on a Disel engine.
# Capacity: 30 passengers
#
# The truck model TATA started with remote ignition.
# Loading capacity: 10000 kg/Ton
# The TATA is now driving.
# It has a sitting capacity of 0 passengers
# The vehicle comes with 2 Doors.
# It runs on a Petrol engine.
# Capacity: 0 passengers
